# %% [markdown]
# # IDX Data Analyst Internship

# %% [markdown]
# ## Week 1
# #### downloading the files, setting up python, setting up git, cleaning data.

# %%
#Imports
import pandas as pd
import crmls_listed
import crmls_sold

# %%
import glob

# %%
df_listings= pd.read_csv("CRMLSListing202602.csv")
df_sold = pd.read_csv("CRMLSSold202602.csv")

# %% [markdown]
# ### Displaying the data frames

# %%
glob.glob("*.csv")
# Out:
# ['CRMLSListing202604.csv',
#  'CRMLSListing202602 (1).csv',
#  'CRMLSListing202602.csv',
#  'CRMLSListing202603.csv',
#  'CRMLSListing202604 (1).csv',
#  'CRMLSSold202602.csv',
#  'CRMLSSold202603.csv',
#  'CRMLSSold202604.csv']

# %%
len(glob.glob("CRMLSSold*.csv"))
# Out:
# 3

# %%
sold_files = glob.glob("CRMLSSold*.csv")
listed_files = glob.glob("CRMLSListing*.csv")

print(len(sold_files))
print(len(listed_files))
# Out:
# 3
# 5

# %%
import os
os.listdir()
# Out:
# ['CRMLSListing202604.csv',
#  'CRMLSListing202602 (1).csv',
#  '.DS_Store',
#  'crmls_sold.py',
#  'CRMLSListing202602.csv',
#  'CRMLSListing202603.csv',
#  '__pycache__',
#  'README.md',
#  'CRMLSListing202604 (1).csv',
#  '.gitignore',
#  'CRMLSSold202602.csv',
#  'CRMLSSold202603.csv',
#  '.git',
#  'CRMLSSold202604.csv',
#  'crmls_listed.py',
#  'analysis.ipynb',
#  'raw']

# %%
sold_files = glob.glob("raw/CRMLSSold*.csv")
df_sold = pd.concat([pd.read_csv(f, low_memory= False) for f in sold_files], ignore_index=True)

# %%
df_listings = pd.concat(
    [pd.read_csv(f, low_memory=False) for f in listed_files],
    ignore_index=True)

# %%
# Looking at the original data set 
df_sold
# Out:
#                    BuyerAgentAOR              ListAgentAOR Flooring ViewYN  \
# 0                        Arcadia                   Arcadia      NaN  False
# 1                         Conejo                    Conejo      NaN   True
# 2                   OrangeCounty              OrangeCounty      NaN   True
# 3       SouthwestRiversideCounty  SouthwestRiversideCounty      NaN   True
# 4                     HighDesert                HighDesert      NaN   True
# ...                          ...                       ...      ...    ...
# 532590                       NaN                       NaN      NaN    NaN
# 532591                       NaN                       NaN      NaN   True
# 532592                       NaN                       NaN      NaN   True
# 532593                       NaN                       NaN      NaN  False
# 532594                       NaN                       NaN      NaN   True
#
#        WaterfrontYN BasementYN PoolPrivateYN  OriginalListPrice  ListingKey  \
# 0               NaN        NaN         False          1,130,000   538338723
# 1               NaN        NaN           NaN          1,795,000   535502637
# 2               NaN        NaN           NaN             99,000   495549184
# 3               NaN        NaN           NaN             40,000   446937009
# 4               NaN        NaN           NaN             59,900   446912267
# ...             ...        ...           ...                ...         ...
# 532590          NaN        NaN           NaN            649,000  1008475397
# 532591          NaN        NaN           NaN             75,689  1003434877
# 532592          NaN        NaN           NaN            275,000  1002713752
# 532593          NaN        NaN         False             10,000  1002447928
# 532594          NaN        NaN           NaN          1,600,000  1001660596
#
#                               ListAgentEmail  ... PostalCode  AssociationFee  \
# 0                        espi.bagwell@kw.com  ...      91016               0
# 1                         david@mabryflp.com  ...      93021             NaN
# 2                Jaredengberg@rocketmail.com  ...      92283               0
# 3                   Julie@whitehornhomes.com  ...      92530               0
# 4                    nadinesells4u@gmail.com  ...      92327               0
# ...                                      ...  ...        ...             ...
# 532590              chiggamasta424@gmail.com  ...      90805             NaN
# 532591        jhisquierdo@lee-associates.com  ...      92371             NaN
# 532592                MLS@DaltonRealtors.com  ...      92082               0
# 532593  Tazzie@CoronadoPremierProperties.com  ...      92118               0
# 532594                diana@countryqueen.com  ...      91765             294
#
#        LotSizeSquareFeet MiddleOrJuniorSchoolDistrict  latfilled  lonfilled  \
# 0                 14,390                          NaN        NaN        NaN
# 1                666,032                          NaN        NaN        NaN
# 2                871,200                          NaN        NaN        NaN
# 3                 16,553                          NaN        NaN        NaN
# 4                275,800                          NaN        NaN        NaN
# ...                  ...                          ...        ...        ...
# 532590             4,682                          NaN        NaN        NaN
# 532591           946,123                          NaN        NaN        NaN
# 532592           619,859                          NaN        NaN        NaN
# 532593               NaN                          NaN        NaN        NaN
# 532594            52,212                          NaN        NaN        NaN
#
#        OriginatingSystemName OriginatingSystemSubName  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ...                      ...                      ...
# 532590                   NaN                      NaN
# 532591                   NaN                      NaN
# 532592                   NaN                      NaN
# 532593                   NaN                      NaN
# 532594                   NaN                      NaN
#
#         BuyerAgencyCompensationType  BuyerAgencyCompensation
# 0                               NaN                      NaN
# 1                               NaN                      NaN
# 2                               NaN                      NaN
# 3                               NaN                      NaN
# 4                               NaN                      NaN
# ...                             ...                      ...
# 532590                        Item1                        2
# 532591                        Item1                        4
# 532592                        Item1                        2
# 532593                         Item                      100
# 532594                        Item1                        2
#
# [532595 rows x 84 columns]

# %%
#Looking at the original data set
df_listings
# Out:
#         OriginalListPrice  ListingKey                 ListAgentEmail  \
# 0                 569,000  1159577837      drad4realestate@gmail.com
# 1                 878,000  1159577818  catherinerealestate@gmail.com
# 2               1,599,000  1159577546         angelelliott@gmail.com
# 3                 850,000  1159577050     christine.akka@compass.com
# 4                   1,900  1159576651          rfolmar2012@gmail.com
# ...                   ...         ...                            ...
# 178259          1,375,000  1151355330        ammarkosgroup@gmail.com
# 178260            985,000  1149517845           aisaethan@icloud.com
# 178261            450,000  1147219386   nathaly@shoppingsdhouses.com
# 178262            249,000  1145273331       BillSoCalCoast@gmail.com
# 178263          1,056,400  1144232364        brokerosborne@gmail.com
#
#          CloseDate  ClosePrice ListAgentFirstName ListAgentLastName  Latitude  \
# 0              NaN         NaN           Danielle       Siani-Rader        34
# 1              NaN         NaN          Catherine             Duong        33
# 2              NaN         NaN              Angel           Elliott        33
# 3              NaN         NaN          Christine              Akka        33
# 4              NaN         NaN             Rodney            Folmar        34
# ...            ...         ...                ...               ...       ...
# 178259         NaN         NaN              Athir            Markos        33
# 178260         NaN         NaN               Aisa                Tu        34
# 178261         NaN         NaN            Nathaly              Vera        33
# 178262         NaN         NaN               Bill            Church        33
# 178263  2026-02-05     965,200               John           Osborne        34
#
#         Longitude            UnparsedAddress  ... MainLevelBedrooms  \
# 0            -116  69707 Northhampton Avenue  ...               NaN
# 1            -117       200 River Rock Court  ...                 0
# 2            -118   27081 Camino De Estrella  ...               NaN
# 3            -117             1826 Priest St  ...               NaN
# 4            -117        5001 W. Florida 129  ...                 2
# ...           ...                        ...  ...               ...
# 178259       -117         1161 N Anza Street  ...               NaN
# 178260       -117      33115 Evergreen Sreet  ...                 2
# 178261       -117        9860 Dale Avenue D2  ...               NaN
# 178262       -117         Little Canyon Lane  ...               NaN
# 178263       -115      9165 Intake Boulevard  ...               NaN
#
#         NewConstructionYN  GarageSpaces     HighSchoolDistrict PostalCode  \
# 0                   False             2                    NaN      92234
# 1                   False             2                 Santee      92071
# 2                   False             2                    NaN      92624
# 3                   False             2                    NaN      92021
# 4                   False             1          Hemet Unified      92545
# ...                   ...           ...                    ...        ...
# 178259                NaN           NaN                    NaN      92021
# 178260                NaN             3  Lake Elsinore Unified      92530
# 178261                NaN             0                  Other      91977
# 178262                NaN           NaN                    NaN      92026
# 178263                NaN           NaN                    NaN      92225
#
#        BuyerOfficeName.1 AssociationFee LotSizeSquareFeet  \
# 0                    NaN            NaN             7,405
# 1                    NaN            256           213,418
# 2                    NaN              0             6,500
# 3                    NaN            158               NaN
# 4                    NaN            NaN             2,500
# ...                  ...            ...               ...
# 178259               NaN              0           222,156
# 178260               NaN              0            14,810
# 178261               NaN            510            91,040
# 178262               NaN            210            37,897
# 178263         SimpliHOM            NaN         3,445,160
#
#        MiddleOrJuniorSchoolDistrict          UnparsedAddress.1
# 0                               NaN  69707 Northhampton Avenue
# 1                               NaN       200 River Rock Court
# 2                               NaN   27081 Camino De Estrella
# 3                               NaN             1826 Priest St
# 4                               NaN        5001 W. Florida 129
# ...                             ...                        ...
# 178259                          NaN         1161 N Anza Street
# 178260                          NaN      33115 Evergreen Sreet
# 178261                          NaN        9860 Dale Avenue D2
# 178262                          NaN         Little Canyon Lane
# 178263                          NaN      9165 Intake Boulevard
#
# [178264 rows x 82 columns]

# %%
df_listings_mar = pd.read_csv("CRMLSListing202603.csv")
df_listings_apr = pd.read_csv("CRMLSListing202604.csv")

# %%
df_listings_all = pd.concat(
    [df_listings, df_listings_mar, df_listings_apr],
    ignore_index=True
)

# %%
print(df_listings_all.shape)
df_listings_all.head()
# Out:
# (256301, 82)
#    OriginalListPrice  ListingKey                 ListAgentEmail CloseDate  \
# 0            569,000  1159577837      drad4realestate@gmail.com       NaN
# 1            878,000  1159577818  catherinerealestate@gmail.com       NaN
# 2          1,599,000  1159577546         angelelliott@gmail.com       NaN
# 3            850,000  1159577050     christine.akka@compass.com       NaN
# 4              1,900  1159576651          rfolmar2012@gmail.com       NaN
#
#    ClosePrice ListAgentFirstName ListAgentLastName  Latitude  Longitude  \
# 0         NaN           Danielle       Siani-Rader        34       -116
# 1         NaN          Catherine             Duong        33       -117
# 2         NaN              Angel           Elliott        33       -118
# 3         NaN          Christine              Akka        33       -117
# 4         NaN             Rodney            Folmar        34       -117
#
#              UnparsedAddress  ... MainLevelBedrooms  NewConstructionYN  \
# 0  69707 Northhampton Avenue  ...               NaN              False
# 1       200 River Rock Court  ...                 0              False
# 2   27081 Camino De Estrella  ...               NaN              False
# 3             1826 Priest St  ...               NaN              False
# 4        5001 W. Florida 129  ...                 2              False
#
#    GarageSpaces  HighSchoolDistrict PostalCode BuyerOfficeName.1  \
# 0             2                 NaN      92234               NaN
# 1             2              Santee      92071               NaN
# 2             2                 NaN      92624               NaN
# 3             2                 NaN      92021               NaN
# 4             1       Hemet Unified      92545               NaN
#
#   AssociationFee LotSizeSquareFeet MiddleOrJuniorSchoolDistrict  \
# 0            NaN             7,405                          NaN
# 1            256           213,418                          NaN
# 2              0             6,500                          NaN
# 3            158               NaN                          NaN
# 4            NaN             2,500                          NaN
#
#            UnparsedAddress.1
# 0  69707 Northhampton Avenue
# 1       200 River Rock Court
# 2   27081 Camino De Estrella
# 3             1826 Priest St
# 4        5001 W. Florida 129
#
# [5 rows x 82 columns]

# %%
df_sold_mar = pd.read_csv("CRMLSSold202603.csv")
df_sold_apr = pd.read_csv("CRMLSSold202604.csv")
# Combine sold data
df_sold_all = pd.concat(
    [df_sold, df_sold_mar, df_sold_apr],
    ignore_index=True
)

print(df_sold_all.shape)
df_sold_all.head()
# Out:
# (580401, 84)
#               BuyerAgentAOR              ListAgentAOR Flooring ViewYN  \
# 0                   Arcadia                   Arcadia      NaN  False
# 1                    Conejo                    Conejo      NaN   True
# 2              OrangeCounty              OrangeCounty      NaN   True
# 3  SouthwestRiversideCounty  SouthwestRiversideCounty      NaN   True
# 4                HighDesert                HighDesert      NaN   True
#
#   WaterfrontYN BasementYN PoolPrivateYN  OriginalListPrice  ListingKey  \
# 0          NaN        NaN         False          1,130,000   538338723
# 1          NaN        NaN           NaN          1,795,000   535502637
# 2          NaN        NaN           NaN             99,000   495549184
# 3          NaN        NaN           NaN             40,000   446937009
# 4          NaN        NaN           NaN             59,900   446912267
#
#                 ListAgentEmail  ... PostalCode  AssociationFee  \
# 0          espi.bagwell@kw.com  ...      91016               0
# 1           david@mabryflp.com  ...      93021             NaN
# 2  Jaredengberg@rocketmail.com  ...      92283               0
# 3     Julie@whitehornhomes.com  ...      92530               0
# 4      nadinesells4u@gmail.com  ...      92327               0
#
#   LotSizeSquareFeet MiddleOrJuniorSchoolDistrict  latfilled  lonfilled  \
# 0            14,390                          NaN        NaN        NaN
# 1           666,032                          NaN        NaN        NaN
# 2           871,200                          NaN        NaN        NaN
# 3            16,553                          NaN        NaN        NaN
# 4           275,800                          NaN        NaN        NaN
#
#   OriginatingSystemName OriginatingSystemSubName  BuyerAgencyCompensationType  \
# 0                   NaN                      NaN                          NaN
# 1                   NaN                      NaN                          NaN
# 2                   NaN                      NaN                          NaN
# 3                   NaN                      NaN                          NaN
# 4                   NaN                      NaN                          NaN
#
#    BuyerAgencyCompensation
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
#
# [5 rows x 84 columns]

# %% [markdown]
# #### Creating new data frames named df_sold_residential, and df_listings_residential, that contain only observations of residential homes.

# %%
# Looking at the property types in the data set before filtering
df_sold['PropertySubType'].value_counts()
# single family residence seems to be the largest sold property type
# Out:
# PropertySubType
# SingleFamilyResidence    326253
# Condominium               92138
# Townhouse                 30770
# Apartment                 11795
# Duplex                    10090
# ManufacturedOnLand         5427
# Quadruplex                 3156
# Triplex                    3104
# StockCooperative           1802
# MixedUse                   1615
# Office                     1436
# Retail                      952
# Industrial                  612
# Cabin                       445
# Studio                      380
# Business                    358
# Warehouse                   266
# RoomingHouse                246
# SpecialPurpose              134
# MultiFamily                 125
# BoatSlip                    104
# Agriculture                  78
# UnimprovedLand               67
# OwnYourOwn                   67
# WaterPositionWithLand        64
# Loft                         62
# MobileHome                   55
# ManufacturedHome             52
# Timeshare                    17
# CoOwnership                  16
# Farm                         16
# HotelMotel                   14
# DeededParking                 7
# Ranch                         3
# Name: count, dtype: int64

# %%
df_listings['PropertyType'].value_counts()
# residential homes are the largest listed property in the data.
# Out:
# PropertyType
# Residential            117488
# ResidentialLease        32737
# Land                    11103
# ResidentialIncome        7185
# ManufacturedInPark       5083
# CommercialSale           2445
# CommercialLease          1676
# BusinessOpportunity       547
# Name: count, dtype: int64

# %%
# filtering csv files to property type == Residential.
df_sold_residential = df_sold_all[df_sold_all["PropertyType"]=="Residential"]
df_listings_residential = df_listings_all[df_listings_all["PropertyType"] == "Residential"]

# %%
# checking he data sets that have been filtered
df_sold_residential['PropertyType'].value_counts()
# Out:
# PropertyType
# Residential    391803
# Name: count, dtype: int64

# %%
df_listings_residential['PropertyType'].value_counts()
# Out:
# PropertyType
# Residential    169542
# Name: count, dtype: int64

# %% [markdown]
# #### Looking at the number of rows and columns in the data sets.

# %%
df_listings.shape
# Out:
# (178264, 82)

# %%
df_sold.shape
# Out:
# (532595, 84)

# %%
df_listings_residential.shape
# Out:
# (169542, 82)

# %%
df_sold_residential.shape
# Out:
# (391803, 84)

# %% [markdown]
# #### What is the Residential vs. other property type share?

# %%
df_sold['PropertyType'].value_counts(normalize=True) * 100
# Out:
# PropertyType
# Residential           67
# ResidentialLease      23
# Land                   3
# ManufacturedInPark     3
# ResidentialIncome      3
# CommercialSale         1
# CommercialLease        1
# BusinessOpportunity    0
# Name: proportion, dtype: float64

# %% [markdown]
# #### The residential properties make up majority of the data, with 67% share compared to other property types. The second largest share is Residential lease.

# %% [markdown]
# Looking at the columns and the number of rows of the new and old data set. The original data sets are significantly larger compared to the new filtered data sets.
#
# df_listings has 31410 rows and 81 colums, df_sold has 532595 rows and 84 columns.
#
# I expect the new data frames to have the same amount of columns which it did, and the rows to reduce,
#
# df_listings_residential has 19997 rows and 81 columns, and df_sold_residential has 359471 rows and 84 columns.

# %% [markdown]
# Deliverable – Week 1
# Submit a .py script that concatenates all monthly files from January 2024 through the most recently
# completed calendar month into two combined datasets (listings and sold), filters both to PropertyType ==
# ‘Residential’ only, and saves them as new CSVs. Include comments confirming row counts before and
# after concatenation and before and after the Residential filter

# %% [markdown]
# #### Deliverable – Weeks 2–3
# Submit a .py script documenting unique property types found, the filtering logic applied, and a null-count
# summary table. Include a missing value report flagging any columns above 90% null. Produce a numeric
# distribution summary (min, max, mean, median, percentiles) for ClosePrice, LivingArea, and
# DaysOnMarket. Save the filtered dataset as a new CSV.

# %%
#Displaying column names to filter data and create new data frames.
df_sold_residential.columns
# Out:
# Index(['BuyerAgentAOR', 'ListAgentAOR', 'Flooring', 'ViewYN', 'WaterfrontYN',
#        'BasementYN', 'PoolPrivateYN', 'OriginalListPrice', 'ListingKey',
#        'ListAgentEmail', 'CloseDate', 'ClosePrice', 'ListAgentFirstName',
#        'ListAgentLastName', 'Latitude', 'Longitude', 'UnparsedAddress',
#        'PropertyType', 'LivingArea', 'ListPrice', 'DaysOnMarket',
#        'ListOfficeName', 'BuyerOfficeName', 'CoListOfficeName',
#        'ListAgentFullName', 'CoListAgentFirstName', 'CoListAgentLastName',
#        'BuyerAgentMlsId', 'BuyerAgentFirstName', 'BuyerAgentLastName',
#        'FireplacesTotal', 'AssociationFeeFrequency', 'AboveGradeFinishedArea',
#        'ListingKeyNumeric', 'MLSAreaMajor', 'TaxAnnualAmount',
#        'CountyOrParish', 'MlsStatus', 'ElementarySchool', 'AttachedGarageYN',
#        'ParkingTotal', 'BuilderName', 'PropertySubType', 'LotSizeAcres',
#        'SubdivisionName', 'BuyerOfficeAOR', 'YearBuilt', 'StreetNumberNumeric',
#        'ListingId', 'BathroomsTotalInteger', 'City', 'TaxYear',
#        'BuildingAreaTotal', 'BedroomsTotal', 'ContractStatusChangeDate',
#        'ElementarySchoolDistrict', 'CoBuyerAgentFirstName',
#        'PurchaseContractDate', 'ListingContractDate', 'BelowGradeFinishedArea',
#        'BusinessType', 'StateOrProvince', 'CoveredSpaces',
#        'MiddleOrJuniorSchool', 'FireplaceYN', 'Stories', 'HighSchool',
#        'Levels', 'LotSizeDimensions', 'LotSizeArea', 'MainLevelBedrooms',
#        'NewConstructionYN', 'GarageSpaces', 'HighSchoolDistrict', 'PostalCode',
#        'AssociationFee', 'LotSizeSquareFeet', 'MiddleOrJuniorSchoolDistrict',
#        'latfilled', 'lonfilled', 'OriginatingSystemName',
#        'OriginatingSystemSubName', 'BuyerAgencyCompensationType',
#        'BuyerAgencyCompensation'],
#       dtype='object')

# %%
df_listings_residential.columns
# Out:
# Index(['OriginalListPrice', 'ListingKey', 'ListAgentEmail', 'CloseDate',
#        'ClosePrice', 'ListAgentFirstName', 'ListAgentLastName', 'Latitude',
#        'Longitude', 'UnparsedAddress', 'PropertyType', 'LivingArea',
#        'ListPrice', 'DaysOnMarket', 'ListOfficeName', 'BuyerOfficeName',
#        'CoListOfficeName', 'ListAgentFullName', 'CoListAgentFirstName',
#        'CoListAgentLastName', 'BuyerAgentMlsId', 'BuyerAgentFirstName',
#        'BuyerAgentLastName', 'FireplacesTotal', 'AssociationFeeFrequency',
#        'AboveGradeFinishedArea', 'ListingKeyNumeric', 'MLSAreaMajor',
#        'TaxAnnualAmount', 'CountyOrParish', 'PropertyType.1', 'MlsStatus',
#        'ElementarySchool', 'ListAgentFirstName.1', 'AttachedGarageYN',
#        'ParkingTotal', 'BuilderName', 'PropertySubType', 'LotSizeAcres',
#        'SubdivisionName', 'BuyerOfficeAOR', 'YearBuilt', 'DaysOnMarket.1',
#        'StreetNumberNumeric', 'LivingArea.1', 'ListingId',
#        'BathroomsTotalInteger', 'City', 'TaxYear', 'BuildingAreaTotal',
#        'BedroomsTotal', 'ContractStatusChangeDate', 'Longitude.1',
#        'ElementarySchoolDistrict', 'CoBuyerAgentFirstName',
#        'PurchaseContractDate', 'ListingContractDate', 'BelowGradeFinishedArea',
#        'BusinessType', 'Latitude.1', 'ListPrice.1', 'StateOrProvince',
#        'CoveredSpaces', 'MiddleOrJuniorSchool', 'FireplaceYN', 'Stories',
#        'HighSchool', 'Levels', 'ListAgentLastName.1', 'CloseDate.1',
#        'LotSizeDimensions', 'LotSizeArea', 'MainLevelBedrooms',
#        'NewConstructionYN', 'GarageSpaces', 'HighSchoolDistrict', 'PostalCode',
#        'BuyerOfficeName.1', 'AssociationFee', 'LotSizeSquareFeet',
#        'MiddleOrJuniorSchoolDistrict', 'UnparsedAddress.1'],
#       dtype='object')

# %% [markdown]
# ### Creatign new data frames with our variables of interest:
#
# #### Key MLS Fields
#
# List Price / Close Price — Transaction pricing data
#
# Square Footage — Property size metrics
#
# (LivingArea)
# Bedrooms / Bathrooms — Property configuration
#
# Property Type — Residential, Condo, etc.
#
# Listing Agent / Brokerage — Agent and firm attribution
#
# Days on Market (DaysOnMarket) — Time-to-sell metric

# %%
df_sold_new = df_sold_residential.copy()
df_sold_new
# Out:
#            BuyerAgentAOR      ListAgentAOR           Flooring ViewYN  \
# 0                Arcadia           Arcadia                NaN  False
# 7       CaliforniaDesert  CaliforniaDesert               Tile   True
# 8                 Laguna            Laguna               Wood   True
# 9       PacificSouthwest  PacificSouthwest                NaN   True
# 10      TheInlandGateway  TheInlandGateway  Carpet,Stone,Tile   True
# ...                  ...               ...                ...    ...
# 580369        LakeCounty        LakeCounty                NaN   True
# 580371  TheInlandGateway  TheInlandGateway   Carpet,Tile,Wood  False
# 580374          SanDiego       TriCounties              Vinyl   True
# 580375             Mrmls      OrangeCounty                NaN   True
# 580382         Southland       PacificWest       Carpet,Vinyl  False
#
#        WaterfrontYN BasementYN PoolPrivateYN  OriginalListPrice  ListingKey  \
# 0               NaN        NaN         False          1,130,000   538338723
# 7               NaN        NaN          True          1,995,000  1089077716
# 8               NaN        NaN          True          2,340,000  1089076111
# 9               NaN        NaN          True            984,000  1089075731
# 10              NaN        NaN         False          1,250,000  1089075621
# ...             ...        ...           ...                ...         ...
# 580369          NaN       True         False            279,000  1069708148
# 580371          NaN       True         False            449,000  1067010583
# 580374          NaN        NaN         False          1,579,000  1063196193
# 580375          NaN        NaN         False            855,000  1062106215
# 580382          NaN        NaN         False            375,000  1052387780
#
#                         ListAgentEmail  ... PostalCode  AssociationFee  \
# 0                  espi.bagwell@kw.com  ...      91016               0
# 7              john@johnbomgardner.com  ...      92270             850
# 8          andrea@ballesterosgroup.com  ...      92677             240
# 9       Cindy@kellemsrealtyproject.com  ...      92119               0
# 10                 lynnw@loislauer.com  ...      92373             425
# ...                                ...  ...        ...             ...
# 580369     jessica.homesells@gmail.com  ...      95424               0
# 580371          brian@cohen-realty.com  ...      92322               0
# 580374               info@homecoin.com  ...      93619               0
# 580375            jefflachef@gmail.com  ...      92629               0
# 580382      elizabethoryan04@gmail.com  ...      90302             345
#
#        LotSizeSquareFeet MiddleOrJuniorSchoolDistrict  latfilled  lonfilled  \
# 0                 14,390                          NaN        NaN        NaN
# 7                 18,295                          NaN        NaN        NaN
# 8                 11,900                          NaN        NaN        NaN
# 9                  6,500                          NaN        NaN        NaN
# 10                 5,338                          NaN        NaN        NaN
# ...                  ...                          ...        ...        ...
# 580369            10,019                          NaN        NaN        NaN
# 580371            12,096                          NaN        NaN        NaN
# 580374           859,874                          NaN        NaN        NaN
# 580375             2,733                          NaN        NaN        NaN
# 580382            23,878                          NaN        NaN        NaN
#
#        OriginatingSystemName OriginatingSystemSubName  \
# 0                        NaN                      NaN
# 7                        NaN                      NaN
# 8                        NaN                      NaN
# 9                        NaN                      NaN
# 10                       NaN                      NaN
# ...                      ...                      ...
# 580369                 CRMLS                CRMLS_CRM
# 580371                 CRMLS                CRMLS_CRM
# 580374                 CRMLS                CRMLS_CRM
# 580375                 CRMLS                CRMLS_CRM
# 580382                 CRMLS                CRMLS_CRM
#
#         BuyerAgencyCompensationType  BuyerAgencyCompensation
# 0                               NaN                      NaN
# 7                               NaN                      NaN
# 8                               NaN                      NaN
# 9                               NaN                      NaN
# 10                              NaN                      NaN
# ...                             ...                      ...
# 580369                          NaN                      NaN
# 580371                          NaN                      NaN
# 580374                          NaN                      NaN
# 580375                          NaN                      NaN
# 580382                          NaN                      NaN
#
# [391803 rows x 84 columns]

# %%
df_listing_new= df_listings_residential.copy()
df_listing_new
# Out:
#         OriginalListPrice  ListingKey                 ListAgentEmail  \
# 0                 569,000  1159577837      drad4realestate@gmail.com
# 1                 878,000  1159577818  catherinerealestate@gmail.com
# 3                 850,000  1159577050     christine.akka@compass.com
# 5                 759,999  1159576072    sally.abdelshahed@gmail.com
# 6               1,995,000  1159576069       alexis@alexisestates.com
# ...                   ...         ...                            ...
# 256289          2,595,000  1153444674        denny@dennykagasoff.com
# 256291          7,285,000  1152609167         ann@brizolisjanzen.com
# 256295            396,000  1151471220      jason@venture-pacific.net
# 256297            985,000  1149517845           aisaethan@icloud.com
# 256298            450,000  1147219386   nathaly@shoppingsdhouses.com
#
#        CloseDate  ClosePrice ListAgentFirstName ListAgentLastName  Latitude  \
# 0            NaN         NaN           Danielle       Siani-Rader        34
# 1            NaN         NaN          Catherine             Duong        33
# 3            NaN         NaN          Christine              Akka        33
# 5            NaN         NaN              Sally       Abdelshahed        34
# 6            NaN         NaN             Alexis    Boris Waterman        34
# ...          ...         ...                ...               ...       ...
# 256289       NaN         NaN              Denny          Kagasoff        34
# 256291       NaN         NaN             K. Ann          Brizolis        33
# 256295       NaN         NaN              Jason          Lipovsky        33
# 256297       NaN         NaN               Aisa                Tu        34
# 256298       NaN         NaN            Nathaly              Vera        33
#
#         Longitude             UnparsedAddress  ... MainLevelBedrooms  \
# 0            -116   69707 Northhampton Avenue  ...               NaN
# 1            -117        200 River Rock Court  ...                 0
# 3            -117              1826 Priest St  ...               NaN
# 5            -118  2886 Villa Catalonia Court  ...                 0
# 6            -118    1522 S Point View Street  ...               NaN
# ...           ...                         ...  ...               ...
# 256289       -118        12004 Briarvale Lane  ...               NaN
# 256291       -117          14480 Bellvista Dr  ...               NaN
# 256295       -117        15755 Davis Cup Lane  ...                 1
# 256297       -117       33115 Evergreen Sreet  ...                 2
# 256298       -117         9860 Dale Avenue D2  ...               NaN
#
#         NewConstructionYN  GarageSpaces     HighSchoolDistrict PostalCode  \
# 0                   False             2                    NaN      92234
# 1                   False             2                 Santee      92071
# 3                   False             2                    NaN      92021
# 5                   False             2   Corona-Norco Unified      92881
# 6                   False             4                    NaN      90035
# ...                   ...           ...                    ...        ...
# 256289              False           NaN                    NaN      91604
# 256291              False             3                    NaN      92067
# 256295                NaN             0         Ramona Unified      92065
# 256297                NaN             3  Lake Elsinore Unified      92530
# 256298                NaN             0                  Other      91977
#
#        BuyerOfficeName.1 AssociationFee LotSizeSquareFeet  \
# 0                    NaN            NaN             7,405
# 1                    NaN            256           213,418
# 3                    NaN            158               NaN
# 5                    NaN            172             2,597
# 6                    NaN            NaN             8,499
# ...                  ...            ...               ...
# 256289               NaN            NaN            24,226
# 256291               NaN            735               NaN
# 256295               NaN            596           831,560
# 256297               NaN              0            14,810
# 256298               NaN            510            91,040
#
#        MiddleOrJuniorSchoolDistrict           UnparsedAddress.1
# 0                               NaN   69707 Northhampton Avenue
# 1                               NaN        200 River Rock Court
# 3                               NaN              1826 Priest St
# 5                               NaN  2886 Villa Catalonia Court
# 6                               NaN    1522 S Point View Street
# ...                             ...                         ...
# 256289                          NaN        12004 Briarvale Lane
# 256291                          NaN          14480 Bellvista Dr
# 256295                          NaN        15755 Davis Cup Lane
# 256297                          NaN       33115 Evergreen Sreet
# 256298                          NaN         9860 Dale Avenue D2
#
# [169542 rows x 82 columns]

# %%
# Convert to datetime (important if it's currently a string)
df_listing_new["ListingContractDate"] = pd.to_datetime(df_listing_new["ListingContractDate"])
df_listing_new["CloseDate"] = pd.to_datetime(df_listing_new["CloseDate"])

# Split into components
df_listing_new["listing_year"] = df_listing_new["ListingContractDate"].dt.year
df_listing_new["listing_month"] = df_listing_new["ListingContractDate"].dt.month
df_listing_new["listing_day"] = df_listing_new["ListingContractDate"].dt.day

df_listing_new["close_year"] = df_listing_new["CloseDate"].dt.year
df_listing_new["close_month"] = df_listing_new["CloseDate"].dt.month
df_listing_new["close_day"] = df_listing_new["CloseDate"].dt.day

# %%
# Convert to datetime (in case they're strings)
df_sold_new["ListingContractDate"] = pd.to_datetime(df_sold_new["ListingContractDate"])
df_sold_new["CloseDate"] = pd.to_datetime(df_sold_new["CloseDate"])

# Split ListingContractDate
df_sold_new["listing_year"] = df_sold_new["ListingContractDate"].dt.year
df_sold_new["listing_month"] = df_sold_new["ListingContractDate"].dt.month
df_sold_new["listing_day"] = df_sold_new["ListingContractDate"].dt.day

# Split CloseDate
df_sold_new["close_year"] = df_sold_new["CloseDate"].dt.year
df_sold_new["close_month"] = df_sold_new["CloseDate"].dt.month
df_sold_new["close_day"] = df_sold_new["CloseDate"].dt.day

# %% [markdown]
# #### Summary statistics of the data frames:

# %%
df_listing_new.describe()
# Out:
#        OriginalListPrice    ListingKey                      CloseDate  \
# count            169,286       169,542                          30555
# mean           1,438,757 1,155,997,178  2026-04-09 18:51:58.232695040
# min                    0 1,139,631,172            2026-02-02 00:00:00
# 25%              595,000 1,154,361,733            2026-03-24 00:00:00
# 50%              869,000 1,156,256,938            2026-04-06 00:00:00
# 75%            1,438,000 1,157,709,128            2026-04-27 00:00:00
# max          819,500,000 1,159,577,837            2030-04-16 00:00:00
# std            6,172,444     1,999,875                            NaN
#
#        ClosePrice  Latitude  Longitude  LivingArea   ListPrice  DaysOnMarket  \
# count      23,675   167,657    167,657     169,387     169,542       169,542
# mean    1,349,263        35       -119       1,983   1,370,783            15
# min        11,900         0       -124           0       5,000           -89
# 25%       650,000        34       -120       1,260     589,991             5
# 50%       935,000        34       -118       1,700     860,000            10
# 75%     1,530,000        35       -117       2,354   1,425,000            20
# max   645,000,000        81        118      70,000 400,000,000           460
# std     4,433,834         2          4       1,291   2,943,308            16
#
#        FireplacesTotal  ...  GarageSpaces  AssociationFee  LotSizeSquareFeet  \
# count                0  ...       159,926         129,344            156,397
# mean               NaN  ...             2             292            386,973
# min                NaN  ...             0               0                  0
# 25%                NaN  ...             2               0              5,227
# 50%                NaN  ...             2             152              7,405
# 75%                NaN  ...             2             440             14,567
# max                NaN  ...           500          49,250      2,106,169,560
# std                NaN  ...             4             630         17,309,372
#
#        MiddleOrJuniorSchoolDistrict  listing_year  listing_month  listing_day  \
# count                             0       169,542        169,542      169,542
# mean                            NaN         2,026              3           15
# min                             NaN         2,026              2            1
# 25%                             NaN         2,026              3            8
# 50%                             NaN         2,026              3           16
# 75%                             NaN         2,026              4           23
# max                             NaN         2,026              4           31
# std                             NaN             0              1            9
#
#        close_year  close_month  close_day
# count      30,555       30,555     30,555
# mean        2,026            4         16
# min         2,026            1          1
# 25%         2,026            3          7
# 50%         2,026            4         16
# 75%         2,026            4         24
# max         2,030           12         31
# std             0            1          9
#
# [8 rows x 43 columns]

# %%
df_sold_new.describe()
# Out:
#        OriginalListPrice    ListingKey                      CloseDate  \
# count            391,100       391,803                         391803
# mean           1,224,946 1,095,588,657  2025-02-03 07:01:38.158513408
# min                    0   421,678,487            2024-01-01 00:00:00
# 25%              588,000 1,074,995,049            2024-07-10 00:00:00
# 50%              829,000 1,093,646,513            2025-01-29 00:00:00
# 75%            1,299,000 1,114,812,498            2025-08-15 00:00:00
# max        1,390,000,000 1,159,569,217            2026-04-30 00:00:00
# std            6,715,292    30,152,621                            NaN
#
#        ClosePrice  Latitude  Longitude  LivingArea   ListPrice  DaysOnMarket  \
# count     391,801   375,942    375,942     391,584     391,803       391,803
# mean    1,193,119        35       -119       1,906   1,141,700            37
# min             0      -117       -178           0         525          -288
# 25%       575,000        34       -119       1,248     579,000             8
# 50%       825,000        34       -118       1,642     819,000            18
# 75%     1,300,000        35       -117       2,218   1,295,000            47
# max   989,500,000        56        329  17,021,321 137,500,000        12,430
# std     6,200,211         2          3      27,217   1,362,002            53
#
#        FireplacesTotal  ...  AssociationFee  LotSizeSquareFeet  \
# count                0  ...         301,638            361,405
# mean               NaN  ...             235            316,196
# min                NaN  ...               0                  0
# 25%                NaN  ...               0              5,227
# 50%                NaN  ...              95              7,242
# 75%                NaN  ...             368             11,800
# max                NaN  ...         750,000      2,208,317,760
# std                NaN  ...           1,786         15,547,147
#
#        MiddleOrJuniorSchoolDistrict  BuyerAgencyCompensation  listing_year  \
# count                             0                   46,125       391,802
# mean                            NaN                      222         2,024
# min                             NaN                        0         1,984
# 25%                             NaN                        2         2,024
# 50%                             NaN                        2         2,024
# 75%                             NaN                        2         2,025
# max                             NaN                  100,000         2,026
# std                             NaN                    2,590             1
#
#        listing_month  listing_day  close_year  close_month  close_day
# count        391,802      391,802     391,803      391,803    391,803
# mean               6           15       2,025            6         16
# min                1            1       2,024            1          1
# 25%                3            8       2,024            4          8
# 50%                6           15       2,025            6         16
# 75%                9           23       2,025            9         23
# max               12           31       2,026           12         31
# std                3            9           1            3          9
#
# [8 rows x 39 columns]

# %% [markdown]
# the summary statistics of both the data sets are similar when we look at the the mean, median, and the range of the data. the std deviation varies more in the df_sold_new data set, as compared to the df_listings-new data set, which is to be expected as generally properties sold are closed at a lower price than the list.
#
# Looking at the min and max, in the listing data there is a min value of -10 days on market, which is concerning and needs further inspection. Similar observations can be seen for the sold data set with a value of -288. The max value of Days on market of the sold data being 12430 is also concerning because that is very far from the average days on market.

# %% [markdown]
# ### Creating visual summaries of the variables in the data set, to search for extreme values and externalities. that might be affecting the summary of the data.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.float_format = '{:,.0f}'.format
columns = [
    "ClosePrice", "ListPrice", "OriginalListPrice",
    "LivingArea", "LotSizeAcres", "BedroomsTotal",
    "BathroomsTotalInteger", "DaysOnMarket", "YearBuilt", 
]

def analyze_dataset(df, name):
    print(f"\n===== Analysis for {name} =====")
    
    for col in columns:
        print(f"\n--- {col} ---")
        
        # Summary stats
        print(df[col].describe(percentiles=[0.01, 0.05, 0.5, 0.95, 0.99]))
        
        # Outliers (IQR)
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        
        outliers = df[(df[col] < lower) | (df[col] > upper)]
        print(f"Outliers: {len(outliers)}")
        
        # Plots
        plt.figure(figsize=(12,4))
        
        plt.subplot(1,2,1)
        sns.histplot(df[col], kde=True)
        plt.title(f"{name} - {col} Histogram")
        
        plt.subplot(1,2,2)
        sns.boxplot(x=df[col])
        plt.title(f"{name} - {col} Boxplot")
        
        plt.tight_layout()
        plt.show()

# %%
analyze_dataset(df_sold_new, "Sold Data")
analyze_dataset(df_listing_new, "Listings Data")
# Out:
# ===== Analysis for Sold Data =====
#
# --- ClosePrice ---
# count       391,801
# mean      1,193,119
# std       6,200,211
# min               0
# 1%          204,900
# 5%          340,000
# 50%         825,000
# 95%       2,850,000
# 99%       5,550,000
# max     989,500,000
# Name: ClosePrice, dtype: float64
# Outliers: 29205
# --- ListPrice ---
# count       391,803
# mean      1,141,700
# std       1,362,002
# min             525
# 1%          215,000
# 5%          348,000
# 50%         819,000
# 95%       2,850,000
# 99%       5,695,000
# max     137,500,000
# Name: ListPrice, dtype: float64
# Outliers: 29434
# --- OriginalListPrice ---
# count         391,100
# mean        1,224,946
# std         6,715,292
# min                 0
# 1%            214,000
# 5%            349,900
# 50%           829,000
# 95%         2,900,000
# 99%         5,995,000
# max     1,390,000,000
# Name: OriginalListPrice, dtype: float64
# Outliers: 30582
# --- LivingArea ---
# count      391,584
# mean         1,906
# std         27,217
# min              0
# 1%             605
# 5%             840
# 50%          1,642
# 95%          3,558
# 99%          5,280
# max     17,021,321
# Name: LivingArea, dtype: float64
# Outliers: 17236
# --- LotSizeAcres ---
# count     361,028
# mean           68
# std        16,440
# min             0
# 1%              0
# 5%              0
# 50%             0
# 95%             3
# 99%            11
# max     7,810,698
# Name: LotSizeAcres, dtype: float64
# Outliers: 56651
# --- BedroomsTotal ---
# count   391,794
# mean          3
# std           1
# min           0
# 1%            1
# 5%            2
# 50%           3
# 95%           5
# 99%           6
# max          45
# Name: BedroomsTotal, dtype: float64
# Outliers: 21402
# --- BathroomsTotalInteger ---
# count   391,735
# mean          3
# std           1
# min           0
# 1%            1
# 5%            1
# 50%           2
# 95%           4
# 99%           6
# max         175
# Name: BathroomsTotalInteger, dtype: float64
# Outliers: 17926
# --- DaysOnMarket ---
# count   391,803
# mean         37
# std          53
# min        -288
# 1%            0
# 5%            1
# 50%          18
# 95%         130
# 99%         228
# max      12,430
# Name: DaysOnMarket, dtype: float64
# Outliers: 30431
# --- YearBuilt ---
# count   391,451
# mean      1,979
# std          26
# min       1,776
# 1%        1,912
# 5%        1,930
# 50%       1,979
# 95%       2,022
# 99%       2,025
# max       2,026
# Name: YearBuilt, dtype: float64
# Outliers: 1006
# ===== Analysis for Listings Data =====
#
# --- ClosePrice ---
# count        23,675
# mean      1,349,263
# std       4,433,834
# min          11,900
# 1%          219,116
# 5%          368,700
# 50%         935,000
# 95%       3,381,336
# 99%       6,200,000
# max     645,000,000
# Name: ClosePrice, dtype: float64
# Outliers: 1662
# --- ListPrice ---
# count       169,542
# mean      1,370,783
# std       2,943,308
# min           5,000
# 1%          215,000
# 5%          349,000
# 50%         860,000
# 95%       3,580,000
# 99%       8,850,000
# max     400,000,000
# Name: ListPrice, dtype: float64
# Outliers: 14448
# --- OriginalListPrice ---
# count       169,286
# mean      1,438,757
# std       6,172,444
# min               0
# 1%          209,000
# 5%          349,000
# 50%         869,000
# 95%       3,599,000
# 99%       8,995,000
# max     819,500,000
# Name: OriginalListPrice, dtype: float64
# Outliers: 13997
# --- LivingArea ---
# count   169,387
# mean      1,983
# std       1,291
# min           0
# 1%          589
# 5%          825
# 50%       1,700
# 95%       3,932
# 99%       6,462
# max      70,000
# Name: LivingArea, dtype: float64
# Outliers: 8124
# --- LotSizeAcres ---
# count   156,146
# mean         26
# std       2,237
# min           0
# 1%            0
# 5%            0
# 50%           0
# 95%           4
# 99%          14
# max     559,841
# Name: LotSizeAcres, dtype: float64
# Outliers: 25656
# --- BedroomsTotal ---
# count   169,481
# mean          3
# std           1
# min           0
# 1%            1
# 5%            2
# 50%           3
# 95%           5
# 99%           6
# max          57
# Name: BedroomsTotal, dtype: float64
# Outliers: 644
# --- BathroomsTotalInteger ---
# count   169,536
# mean          3
# std           1
# min           0
# 1%            1
# 5%            1
# 50%           2
# 95%           5
# 99%           7
# max          59
# Name: BathroomsTotalInteger, dtype: float64
# Outliers: 11489
# --- DaysOnMarket ---
# count   169,542
# mean         15
# std          16
# min         -89
# 1%            0
# 5%            0
# 50%          10
# 95%          47
# 99%          74
# max         460
# Name: DaysOnMarket, dtype: float64
# Outliers: 10448
# --- YearBuilt ---
# count   169,255
# mean      1,981
# std          27
# min       1,800
# 1%        1,912
# 5%        1,930
# 50%       1,981
# 95%       2,024
# 99%       2,026
# max       2,027
# Name: YearBuilt, dtype: float64
# Outliers: 438

# %% [markdown]
# ### Questions to think about:
#
# #### What is the Residential vs. other property type share?
# The residential properties make up majority of the data, with 67.4943% share compared to other property types. The second largest share is Residential lease.
#
# #### What are the median and average close prices?
# The mean for sold data(close_price) is approximately $1,188,227. Compared tot he sold data, the listings data(close price) has a mean of is approxmaitely $1,233,658, which is close but higher than the sold price, this might be because the final sale of a property is usually at a lower price than the list price.
#
# The median for the sold data(close_price) is 825,000 which is significantly smaller than the mean value, which means the data contains values that might be skewing the results. Comparing this to the median of the list_data (close_price), it is, 910,000 which is also lower than the mean value.
#
# Overall the columns need to be further investigated.
#
# #### What does the Days on Market distribution look like?
# The days on market distribution has several extreme values that might be due to errors. For the sold_data, 99% of the data is around 223, and for the listing_data 99% of the data is under 63 days.
#
# The extreme values need to be removed, in order for the analysis to be more accurate.
#
# #### What percentage of homes sold above vs. below list price?
# The value above list_price is 41%, and below is 59% for the sold data set.
# The percentage of data above list_price is 18% and below is 82% for the listings data.
#
# #### Are there any apparent date consistency issues (e.g., close date before listing date)?
# Sold Data Issues:
# Close before listing: 54
# Built after listing: 811
# Built after sale: 31
#
# Listing Data Issues:
# Close before listing: 2
# Built after listing: 3
#
# These values need to be further inspected and removed if they are errors.
#
# #### Which counties have the highest median prices?
# The counties which have the highest residential close price, are Del Norte in the sold data, and San Mateo in the listing data.

# %%
#What percentage of homes sold above vs. below list price?
df_sold_new['above_list'] = df_sold_new["ClosePrice"] > df_sold_new["ListPrice"]
df_sold_new['above_list'].value_counts(normalize=True) * 100
# Out:
# above_list
# False   59
# True    41
# Name: proportion, dtype: float64

# %%
# Checking how many values are invalid in terms of close price and list price. 
df_listing_new['above_list'] = df_listing_new["ClosePrice"] > df_listing_new["ListPrice"]
df_listing_new['above_list'].value_counts(normalize=True) * 100
# Out:
# above_list
# False   93
# True     7
# Name: proportion, dtype: float64

# %%
df_sold_new["YearBuilt"].dtype
df_sold_new["invalid_date_order"] = df_sold_new["CloseDate"] < df_sold_new["ListingContractDate"]

df_sold_new["built_after_listing"] = (df_sold_new["YearBuilt"] > df_sold_new["ListingContractDate"].dt.year)

df_sold_new["built_after_sale"] = (df_sold_new["YearBuilt"] > df_sold_new["CloseDate"].dt.year)

# Count issues
print("Sold Data Issues:")
print("Close before listing:", df_sold_new["invalid_date_order"].sum())
print("Built after listing:", df_sold_new["built_after_listing"].sum())
print("Built after sale:", df_sold_new["built_after_sale"].sum())
# Out:
# Sold Data Issues:
# Close before listing: 59
# Built after listing: 921
# Built after sale: 31

# %%
# Checking data consistency issues. 
df_listing_new["invalid_date_order"] = df_listing_new["CloseDate"] < df_listing_new["ListingContractDate"]

df_listing_new["built_after_listing"] = (
    df_listing_new["YearBuilt"] > df_listing_new["ListingContractDate"].dt.year
)

# Count issues
print("\nListing Data Issues:")
print("Close before listing:", df_listing_new["invalid_date_order"].sum())
print("Built after listing:", df_listing_new["built_after_listing"].sum())
# Out:
# Listing Data Issues:
# Close before listing: 14
# Built after listing: 52

# %%
# Checking the largest median value close price counties. Indicating the luxury properties in the data. 
df_sold_residential.groupby("CountyOrParish")["ClosePrice"].median().sort_values(ascending=False)
# Out:
# CountyOrParish
# Del Norte         2,485,000
# Other County      2,462,500
# San Mateo         1,700,000
# Santa Clara       1,600,000
# Santa Cruz        1,200,000
#                      ...
# Imperial            306,000
# Sierra              255,000
# Foreign Country     225,000
# Modoc               225,000
# Lassen              163,750
# Name: ClosePrice, Length: 63, dtype: float64

# %%
df_listings_residential.groupby("CountyOrParish")["ClosePrice"].median().sort_values(ascending=False)
# Out:
# CountyOrParish
# San Mateo         1,960,000
# Santa Clara       1,730,000
# San Francisco     1,480,000
# Santa Cruz        1,435,000
# Orange            1,300,000
# Alameda           1,290,000
# Marin             1,250,000
# Los Angeles         965,000
# Monterey            955,000
# San Diego           950,000
# San Luis Obispo     910,000
# Ventura             900,000
# Contra Costa        900,000
# Napa                875,000
# Santa Barbara       743,500
# San Benito          739,000
# San Joaquin         670,000
# Placer              650,000
# Mono                649,000
# Sonoma              625,000
# Riverside           620,000
# Solano              585,000
# San Bernardino      565,000
# Plumas              565,000
# Mendocino           525,391
# El Dorado           502,000
# Other State         477,700
# Sacramento          454,995
# Nevada              453,000
# Tuolumne            442,250
# Stanislaus          430,000
# Mariposa            429,000
# Calaveras           425,000
# Fresno              425,000
# Madera              412,500
# Butte               407,000
# Tulare              405,000
# Tehama              399,500
# Kings               395,000
# Yuba                395,000
# Merced              390,000
# Shasta              380,000
# Glenn               370,000
# Kern                367,500
# Colusa              348,500
# Lake                307,500
# Siskiyou            270,500
# Imperial            240,250
# Yolo                225,000
# Sutter              170,000
# Amador                  NaN
# Del Norte               NaN
# Foreign Country         NaN
# Humboldt                NaN
# Inyo                    NaN
# Lassen                  NaN
# Modoc                   NaN
# Other                   NaN
# Sierra                  NaN
# Trinity                 NaN
# Name: ClosePrice, dtype: float64

# %% [markdown]
# ## Merging Mortgage data.

# %%
fred_url = "https://fred.stlouisfed.org/graph/fredgraph.csv?id=MORTGAGE30US"

mortgage = pd.read_csv(fred_url)

print("Original mortgage data columns:")
print(mortgage.columns)

print("\nMortgage data preview:")
print(mortgage.head())
# Out:
# Original mortgage data columns:
# Index(['observation_date', 'MORTGAGE30US'], dtype='object')
#
# Mortgage data preview:
#   observation_date  MORTGAGE30US
# 0       1971-04-02             7
# 1       1971-04-09             7
# 2       1971-04-16             7
# 3       1971-04-23             7
# 4       1971-04-30             7

# %%
if "DATE" in mortgage.columns:
    mortgage = pd.read_csv(fred_url, parse_dates=["DATE"])
    mortgage.columns = ["date", "rate_30yr_fixed"]
elif "observation_date" in mortgage.columns:
    mortgage = pd.read_csv(fred_url, parse_dates=["observation_date"])
    mortgage.columns = ["date", "rate_30yr_fixed"]
else:
    raise ValueError("Unexpected FRED mortgage data column names.")

mortgage["rate_30yr_fixed"] = pd.to_numeric(
    mortgage["rate_30yr_fixed"],
    errors="coerce"
)

mortgage["year_month"] = mortgage["date"].dt.to_period("M")

mortgage_monthly = (
    mortgage.groupby("year_month")["rate_30yr_fixed"]
    .mean()
    .reset_index()
)

print("Monthly mortgage rate data:")
print(mortgage_monthly.head())
# Out:
# Monthly mortgage rate data:
#   year_month  rate_30yr_fixed
# 0    1971-04                7
# 1    1971-05                7
# 2    1971-06                8
# 3    1971-07                8
# 4    1971-08                8

# %%
df_sold_new["CloseDate"] = pd.to_datetime(df_sold_new["CloseDate"], errors="coerce")
df_listing_new["ListingContractDate"] = pd.to_datetime(df_listing_new["ListingContractDate"], errors="coerce")

df_sold_new["year_month"] = df_sold_new["CloseDate"].dt.to_period("M")
df_listing_new["year_month"] = df_listing_new["ListingContractDate"].dt.to_period("M")

sold_with_rates = df_sold_new.merge(
    mortgage_monthly,
    on="year_month",
    how="left"
)

listed_with_rates = df_listing_new.merge(
    mortgage_monthly,
    on="year_month",
    how="left"
)

print("Missing mortgage rates in sold dataset:", sold_with_rates["rate_30yr_fixed"].isnull().sum())
print("Missing mortgage rates in listed dataset:", listed_with_rates["rate_30yr_fixed"].isnull().sum())
# Out:
# Missing mortgage rates in sold dataset: 0
# Missing mortgage rates in listed dataset: 0

# %%
print("Sold preview with mortgage rates:")
print(sold_with_rates[["CloseDate", "year_month", "ClosePrice", "rate_30yr_fixed"]].head())

print("\nListed preview with mortgage rates:")
print(listed_with_rates[["ListingContractDate", "year_month", "ListPrice", "rate_30yr_fixed"]].head())
# Out:
# Sold preview with mortgage rates:
#    CloseDate year_month  ClosePrice  rate_30yr_fixed
# 0 2024-09-12    2024-09   1,090,000                6
# 1 2024-09-30    2024-09   1,995,000                6
# 2 2024-09-30    2024-09   2,340,000                6
# 3 2024-09-30    2024-09     984,000                6
# 4 2024-09-30    2024-09   1,225,000                6
#
# Listed preview with mortgage rates:
#   ListingContractDate year_month  ListPrice  rate_30yr_fixed
# 0          2026-04-30    2026-04    569,000                6
# 1          2026-04-26    2026-04    878,000                6
# 2          2026-04-16    2026-04    850,000                6
# 3          2026-04-01    2026-04    759,999                6
# 4          2026-04-14    2026-04  1,995,000                6

# %% [markdown]
# # Week 4-5

# %%
# checking column names 
df_sold_new.columns
# Out:
# Index(['BuyerAgentAOR', 'ListAgentAOR', 'Flooring', 'ViewYN', 'WaterfrontYN',
#        'BasementYN', 'PoolPrivateYN', 'OriginalListPrice', 'ListingKey',
#        'ListAgentEmail', 'CloseDate', 'ClosePrice', 'ListAgentFirstName',
#        'ListAgentLastName', 'Latitude', 'Longitude', 'UnparsedAddress',
#        'PropertyType', 'LivingArea', 'ListPrice', 'DaysOnMarket',
#        'ListOfficeName', 'BuyerOfficeName', 'CoListOfficeName',
#        'ListAgentFullName', 'CoListAgentFirstName', 'CoListAgentLastName',
#        'BuyerAgentMlsId', 'BuyerAgentFirstName', 'BuyerAgentLastName',
#        'FireplacesTotal', 'AssociationFeeFrequency', 'AboveGradeFinishedArea',
#        'ListingKeyNumeric', 'MLSAreaMajor', 'TaxAnnualAmount',
#        'CountyOrParish', 'MlsStatus', 'ElementarySchool', 'AttachedGarageYN',
#        'ParkingTotal', 'BuilderName', 'PropertySubType', 'LotSizeAcres',
#        'SubdivisionName', 'BuyerOfficeAOR', 'YearBuilt', 'StreetNumberNumeric',
#        'ListingId', 'BathroomsTotalInteger', 'City', 'TaxYear',
#        'BuildingAreaTotal', 'BedroomsTotal', 'ContractStatusChangeDate',
#        'ElementarySchoolDistrict', 'CoBuyerAgentFirstName',
#        'PurchaseContractDate', 'ListingContractDate', 'BelowGradeFinishedArea',
#        'BusinessType', 'StateOrProvince', 'CoveredSpaces',
#        'MiddleOrJuniorSchool', 'FireplaceYN', 'Stories', 'HighSchool',
#        'Levels', 'LotSizeDimensions', 'LotSizeArea', 'MainLevelBedrooms',
#        'NewConstructionYN', 'GarageSpaces', 'HighSchoolDistrict', 'PostalCode',
#        'AssociationFee', 'LotSizeSquareFeet', 'MiddleOrJuniorSchoolDistrict',
#        'latfilled', 'lonfilled', 'OriginatingSystemName',
#        'OriginatingSystemSubName', 'BuyerAgencyCompensationType',
#        'BuyerAgencyCompensation', 'listing_year', 'listing_month',
#        'listing_day', 'close_year', 'close_month', 'close_day', 'above_list',
#        'invalid_date_order', 'built_after_listing', 'built_after_sale',
#        'year_month'],
#       dtype='object')

# %% [markdown]
# # Starting Data Cleaning
# ## Data Type
# ### Converting columns with data types that are inconsistent with the data type.

# %%
#Convert date columns to datetime

date_cols = ["CloseDate", "PurchaseContractDate", "ListingContractDate", "ContractStatusChangeDate"]

for col in date_cols:
    if col in df_sold_new.columns:
        df_sold_new[col] = pd.to_datetime(df_sold_new[col], errors='coerce')
        
    if col in df_listing_new.columns:
        df_listing_new[col] = pd.to_datetime(df_listing_new[col], errors='coerce')

# %%
df_sold_new.dtypes
# Out:
# BuyerAgentAOR             object
# ListAgentAOR              object
# Flooring                  object
# ViewYN                    object
# WaterfrontYN              object
#                          ...
# above_list                  bool
# invalid_date_order          bool
# built_after_listing         bool
# built_after_sale            bool
# year_month             period[M]
# Length: 95, dtype: object

# %%
df_listing_new.dtypes
# Out:
# OriginalListPrice             float64
# ListingKey                      int64
# ListAgentEmail                 object
# CloseDate              datetime64[ns]
# ClosePrice                    float64
#                             ...
# close_day                     float64
# above_list                       bool
# invalid_date_order               bool
# built_after_listing              bool
# year_month                  period[M]
# Length: 92, dtype: object

# %% [markdown]
# ## Dublicate columns
# ### Dropping all columns that might be dublicates and got added in the data.

# %%
# droping any columns that might be duplicated. 
df_sold_new = df_sold_new.drop_duplicates()
df_listing_new = df_listing_new.drop_duplicates()

# %%
df_sold_new.columns
# Out:
# Index(['BuyerAgentAOR', 'ListAgentAOR', 'Flooring', 'ViewYN', 'WaterfrontYN',
#        'BasementYN', 'PoolPrivateYN', 'OriginalListPrice', 'ListingKey',
#        'ListAgentEmail', 'CloseDate', 'ClosePrice', 'ListAgentFirstName',
#        'ListAgentLastName', 'Latitude', 'Longitude', 'UnparsedAddress',
#        'PropertyType', 'LivingArea', 'ListPrice', 'DaysOnMarket',
#        'ListOfficeName', 'BuyerOfficeName', 'CoListOfficeName',
#        'ListAgentFullName', 'CoListAgentFirstName', 'CoListAgentLastName',
#        'BuyerAgentMlsId', 'BuyerAgentFirstName', 'BuyerAgentLastName',
#        'FireplacesTotal', 'AssociationFeeFrequency', 'AboveGradeFinishedArea',
#        'ListingKeyNumeric', 'MLSAreaMajor', 'TaxAnnualAmount',
#        'CountyOrParish', 'MlsStatus', 'ElementarySchool', 'AttachedGarageYN',
#        'ParkingTotal', 'BuilderName', 'PropertySubType', 'LotSizeAcres',
#        'SubdivisionName', 'BuyerOfficeAOR', 'YearBuilt', 'StreetNumberNumeric',
#        'ListingId', 'BathroomsTotalInteger', 'City', 'TaxYear',
#        'BuildingAreaTotal', 'BedroomsTotal', 'ContractStatusChangeDate',
#        'ElementarySchoolDistrict', 'CoBuyerAgentFirstName',
#        'PurchaseContractDate', 'ListingContractDate', 'BelowGradeFinishedArea',
#        'BusinessType', 'StateOrProvince', 'CoveredSpaces',
#        'MiddleOrJuniorSchool', 'FireplaceYN', 'Stories', 'HighSchool',
#        'Levels', 'LotSizeDimensions', 'LotSizeArea', 'MainLevelBedrooms',
#        'NewConstructionYN', 'GarageSpaces', 'HighSchoolDistrict', 'PostalCode',
#        'AssociationFee', 'LotSizeSquareFeet', 'MiddleOrJuniorSchoolDistrict',
#        'latfilled', 'lonfilled', 'OriginatingSystemName',
#        'OriginatingSystemSubName', 'BuyerAgencyCompensationType',
#        'BuyerAgencyCompensation', 'listing_year', 'listing_month',
#        'listing_day', 'close_year', 'close_month', 'close_day', 'above_list',
#        'invalid_date_order', 'built_after_listing', 'built_after_sale',
#        'year_month'],
#       dtype='object')

# %% [markdown]
# ## Invalid values
# #### Creating column which records all teh invalid values in both data sets and then removing them.

# %%
df_sold_new["invalid_values"] = (
    (df_sold_new["ClosePrice"] <= 0) |
    (df_sold_new["LivingArea"] <= 0) |
    (df_sold_new["DaysOnMarket"] < 0) |
    (df_sold_new["BedroomsTotal"] < 0) |
    (df_sold_new["BathroomsTotalInteger"] < 0)
)
df_sold_new
# Out:
# /var/folders/rc/glpd4gfj5j3d7jd2_l2wyzx80000gn/T/ipykernel_67099/902115094.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sold_new["invalid_values"] = (
#            BuyerAgentAOR      ListAgentAOR           Flooring ViewYN  \
# 0                Arcadia           Arcadia                NaN  False
# 7       CaliforniaDesert  CaliforniaDesert               Tile   True
# 8                 Laguna            Laguna               Wood   True
# 9       PacificSouthwest  PacificSouthwest                NaN   True
# 10      TheInlandGateway  TheInlandGateway  Carpet,Stone,Tile   True
# ...                  ...               ...                ...    ...
# 580369        LakeCounty        LakeCounty                NaN   True
# 580371  TheInlandGateway  TheInlandGateway   Carpet,Tile,Wood  False
# 580374          SanDiego       TriCounties              Vinyl   True
# 580375             Mrmls      OrangeCounty                NaN   True
# 580382         Southland       PacificWest       Carpet,Vinyl  False
#
#        WaterfrontYN BasementYN PoolPrivateYN  OriginalListPrice  ListingKey  \
# 0               NaN        NaN         False          1,130,000   538338723
# 7               NaN        NaN          True          1,995,000  1089077716
# 8               NaN        NaN          True          2,340,000  1089076111
# 9               NaN        NaN          True            984,000  1089075731
# 10              NaN        NaN         False          1,250,000  1089075621
# ...             ...        ...           ...                ...         ...
# 580369          NaN       True         False            279,000  1069708148
# 580371          NaN       True         False            449,000  1067010583
# 580374          NaN        NaN         False          1,579,000  1063196193
# 580375          NaN        NaN         False            855,000  1062106215
# 580382          NaN        NaN         False            375,000  1052387780
#
#                         ListAgentEmail  ... listing_day  close_year  \
# 0                  espi.bagwell@kw.com  ...          18        2024
# 7              john@johnbomgardner.com  ...          30        2024
# 8          andrea@ballesterosgroup.com  ...           1        2024
# 9       Cindy@kellemsrealtyproject.com  ...          30        2024
# 10                 lynnw@loislauer.com  ...           2        2024
# ...                                ...  ...         ...         ...
# 580369     jessica.homesells@gmail.com  ...          18        2026
# 580371          brian@cohen-realty.com  ...           8        2026
# 580374               info@homecoin.com  ...          10        2026
# 580375            jefflachef@gmail.com  ...           6        2026
# 580382      elizabethoryan04@gmail.com  ...          13        2026
#
#        close_month close_day  above_list  invalid_date_order  \
# 0                9        12       False               False
# 7                9        30       False               False
# 8                9        30       False               False
# 9                9        30       False               False
# 10               9        30       False               False
# ...            ...       ...         ...                 ...
# 580369           4         1       False               False
# 580371           4        13       False               False
# 580374           4        16       False               False
# 580375           4        16       False               False
# 580382           4        24        True               False
#
#        built_after_listing built_after_sale  year_month  invalid_values
# 0                    False            False     2024-09           False
# 7                    False            False     2024-09           False
# 8                    False            False     2024-09           False
# 9                    False            False     2024-09           False
# 10                   False            False     2024-09           False
# ...                    ...              ...         ...             ...
# 580369               False            False     2026-04           False
# 580371               False            False     2026-04           False
# 580374               False            False     2026-04           False
# 580375               False            False     2026-04           False
# 580382               False            False     2026-04           False
#
# [391755 rows x 96 columns]

# %%
df_listing_new["invalid_values"] = (
    (df_listing_new["ListPrice"] <= 0) |
    (df_listing_new["LivingArea"] <= 0) |
    (df_listing_new["DaysOnMarket"] < 0) |
    (df_listing_new["BedroomsTotal"] < 0) |
    (df_listing_new["BathroomsTotalInteger"] < 0)
)
df_listing_new
# Out:
# /var/folders/rc/glpd4gfj5j3d7jd2_l2wyzx80000gn/T/ipykernel_67099/199487826.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_listing_new["invalid_values"] = (
#         OriginalListPrice  ListingKey                 ListAgentEmail  \
# 0                 569,000  1159577837      drad4realestate@gmail.com
# 1                 878,000  1159577818  catherinerealestate@gmail.com
# 3                 850,000  1159577050     christine.akka@compass.com
# 5                 759,999  1159576072    sally.abdelshahed@gmail.com
# 6               1,995,000  1159576069       alexis@alexisestates.com
# ...                   ...         ...                            ...
# 139237          5,750,000  1151417547                            NaN
# 139238            475,000  1150815309                            NaN
# 139240            825,000  1148377048                            NaN
# 139241          2,849,000  1145743715                            NaN
# 139242          1,649,000  1139631172                            NaN
#
#        CloseDate  ClosePrice ListAgentFirstName ListAgentLastName  Latitude  \
# 0            NaT         NaN           Danielle       Siani-Rader        34
# 1            NaT         NaN          Catherine             Duong        33
# 3            NaT         NaN          Christine              Akka        33
# 5            NaT         NaN              Sally       Abdelshahed        34
# 6            NaT         NaN             Alexis    Boris Waterman        34
# ...          ...         ...                ...               ...       ...
# 139237       NaT         NaN           Jennifer           Okhovat        34
# 139238       NaT         NaN            Melissa             Sofia        33
# 139240       NaT         NaN            Adriana             Gliha        33
# 139241       NaT         NaN               Lori           Barnett        33
# 139242       NaT         NaN             George          Wood Jr.        33
#
#         Longitude             UnparsedAddress  ... listing_month  listing_day  \
# 0            -116   69707 Northhampton Avenue  ...             4           30
# 1            -117        200 River Rock Court  ...             4           26
# 3            -117              1826 Priest St  ...             4           16
# 5            -118  2886 Villa Catalonia Court  ...             4            1
# 6            -118    1522 S Point View Street  ...             4           14
# ...           ...                         ...  ...           ...          ...
# 139237       -118         8732 Rangely Avenue  ...             3            7
# 139238       -117      4600 lamont street 226  ...             3           24
# 139240       -117      1461 Fieldbrook Street  ...             3           12
# 139241       -117       1005 Canvasback Drive  ...             3           18
# 139242       -117          943 Georgia Street  ...             3           25
#
#         close_year  close_month close_day above_list invalid_date_order  \
# 0              NaN          NaN       NaN      False              False
# 1              NaN          NaN       NaN      False              False
# 3              NaN          NaN       NaN      False              False
# 5              NaN          NaN       NaN      False              False
# 6              NaN          NaN       NaN      False              False
# ...            ...          ...       ...        ...                ...
# 139237         NaN          NaN       NaN      False              False
# 139238         NaN          NaN       NaN      False              False
# 139240         NaN          NaN       NaN      False              False
# 139241         NaN          NaN       NaN      False              False
# 139242         NaN          NaN       NaN      False              False
#
#        built_after_listing year_month invalid_values
# 0                    False    2026-04          False
# 1                    False    2026-04          False
# 3                    False    2026-04          False
# 5                    False    2026-04          False
# 6                    False    2026-04          False
# ...                    ...        ...            ...
# 139237               False    2026-03          False
# 139238               False    2026-03          False
# 139240               False    2026-03          False
# 139241               False    2026-03          False
# 139242               False    2026-03          False
#
# [81416 rows x 93 columns]

# %%
df_sold_new["purchase_after_close_flag"] = (
    df_sold_new["PurchaseContractDate"] > df_sold_new["CloseDate"]
)

df_listing_new["purchase_after_close_flag"] = (
    df_listing_new["PurchaseContractDate"] > df_listing_new["CloseDate"]
)
# Out:
# /var/folders/rc/glpd4gfj5j3d7jd2_l2wyzx80000gn/T/ipykernel_67099/3180170519.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sold_new["purchase_after_close_flag"] = (
# /var/folders/rc/glpd4gfj5j3d7jd2_l2wyzx80000gn/T/ipykernel_67099/3180170519.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_listing_new["purchase_after_close_flag"] = (

# %%
# creating invalid variables related to date in sold data. 
df_sold_new["invalid_date_order"] = df_sold_new["CloseDate"] < df_sold_new["ListingContractDate"]

df_sold_new["built_after_listing"] = (df_sold_new["YearBuilt"] > df_sold_new["ListingContractDate"].dt.year)
# Out:
# /var/folders/rc/glpd4gfj5j3d7jd2_l2wyzx80000gn/T/ipykernel_67099/3303658960.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sold_new["invalid_date_order"] = df_sold_new["CloseDate"] < df_sold_new["ListingContractDate"]
# /var/folders/rc/glpd4gfj5j3d7jd2_l2wyzx80000gn/T/ipykernel_67099/3303658960.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sold_new["built_after_listing"] = (df_sold_new["YearBuilt"] > df_sold_new["ListingContractDate"].dt.year)

# %%
# creating invalid values related to date in listings data.
df_listing_new["invalid_date_order"] = ( df_listing_new["CloseDate"] < df_listing_new["ListingContractDate"])

df_listing_new["built_after_listing"] = (df_listing_new["YearBuilt"] > df_listing_new["ListingContractDate"].dt.year)
# Out:
# /var/folders/rc/glpd4gfj5j3d7jd2_l2wyzx80000gn/T/ipykernel_67099/1306655116.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_listing_new["invalid_date_order"] = ( df_listing_new["CloseDate"] < df_listing_new["ListingContractDate"])
# /var/folders/rc/glpd4gfj5j3d7jd2_l2wyzx80000gn/T/ipykernel_67099/1306655116.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_listing_new["built_after_listing"] = (df_listing_new["YearBuilt"] > df_listing_new["ListingContractDate"].dt.year)

# %%
def negative_timeline(df):
    return (
        (df["PurchaseContractDate"] > df["CloseDate"]) |
        (df["ListingContractDate"] > df["CloseDate"]) |
        (df["ContractStatusChangeDate"] > df["CloseDate"])
    )

df_sold_new["negative_timeline_flag"] = negative_timeline(df_sold_new)
df_listing_new["negative_timeline_flag"] = negative_timeline(df_listing_new)
# Out:
# /var/folders/rc/glpd4gfj5j3d7jd2_l2wyzx80000gn/T/ipykernel_67099/4247862575.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sold_new["negative_timeline_flag"] = negative_timeline(df_sold_new)
# /var/folders/rc/glpd4gfj5j3d7jd2_l2wyzx80000gn/T/ipykernel_67099/4247862575.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_listing_new["negative_timeline_flag"] = negative_timeline(df_listing_new)

# %%
# dropping the invalid value variables for sold data. 
df_sold_new = df_sold_new[
    ~(df_sold_new["invalid_values"] |
      df_sold_new["invalid_date_order"] |
      df_sold_new["built_after_listing"])
]

# %%
# dropping the invalid value variables for sold data. 
df_listing_new = df_listing_new[
    ~( df_listing_new["invalid_values"] | df_listing_new["invalid_date_order"] | df_listing_new["built_after_listing"])]

# %% [markdown]
# #### Removing the values that are invalid. As they might skew our analysis.

# %%
# Dropping helper columns as they are not needed for sold data
df_listing_new = df_listing_new.drop(columns=[
    "invalid_values",
    "invalid_date_order",
    "built_after_listing"
])
# Dropping helper columns as they are not needed for sold data
df_sold_new = df_sold_new.drop(columns=[
    "invalid_values",
    "invalid_date_order",
    "built_after_listing"
])

# %% [markdown]
# # Missing values

# %% [markdown]
# ### Checking for the missing values in both data sets and caluculating the percentage of missing values in relation to our entire data.

# %%
# Checking for missing values.
df_sold_new.isna().sum()
# Out:
# BuyerAgentAOR                 49369
# ListAgentAOR                  45923
# Flooring                     139753
# ViewYN                        33438
# WaterfrontYN                 390362
#                               ...
# above_list                        0
# built_after_sale                  0
# year_month                        0
# purchase_after_close_flag         0
# negative_timeline_flag            0
# Length: 95, dtype: int64

# %%
df_listing_new.isna().sum()
# Out:
# OriginalListPrice              109
# ListingKey                       0
# ListAgentEmail               54905
# CloseDate                    65302
# ClosePrice                   68369
#                              ...
# close_day                    65302
# above_list                       0
# year_month                       0
# purchase_after_close_flag        0
# negative_timeline_flag           0
# Length: 92, dtype: int64

# %% [markdown]
# #### Calculating the percent of null values in the data

# %%
(df_sold_new.isnull().mean() *100).round(4)
# Out:
# BuyerAgentAOR                13
# ListAgentAOR                 12
# Flooring                     36
# ViewYN                        9
# WaterfrontYN                100
#                              ..
# above_list                    0
# built_after_sale              0
# year_month                    0
# purchase_after_close_flag     0
# negative_timeline_flag        0
# Length: 95, dtype: float64

# %% [markdown]
# #### Their are no values that I am particularly concerned about dropping, the most significant missing value is 8% of the lotsize acre column, however I dont think removing 8% of the data for lot size is needed.

# %%
(df_listing_new.isnull().mean()*100).round(4)
# Out:
# OriginalListPrice            0
# ListingKey                   0
# ListAgentEmail              68
# CloseDate                   80
# ClosePrice                  84
#                             ..
# close_day                   80
# above_list                   0
# year_month                   0
# purchase_after_close_flag    0
# negative_timeline_flag       0
# Length: 92, dtype: float64

# %% [markdown]
# #### for listing data, I see that about 64% values in the close date of the listing data is missing. This is not concerning to me considering that this is the listings data. I will not be dropping these values as I would loose 64% of the data in the process which might affect our analysis. instead, I will drop the values when particularly analysing the close data column.

# %% [markdown]
# ## Cleaning Latitude and longitude data.
#
# ### Creating flags for:
# #### • Flag records with missing coordinates (Latitude or Longitude is null)
# #### • Flag Latitude = 0 or Longitude = 0 (sentinel null values)
# #### • Flag Longitude > 0 errors (California coordinates should be negative)
# #### • Flag out-of-state or implausible coordinates

# %%
df_sold_new["missing_coords_flag"] = (
    df_sold_new["Latitude"].isna() | df_sold_new["Longitude"].isna()
)

df_listing_new["missing_coords_flag"] = (
    df_listing_new["Latitude"].isna() | df_listing_new["Longitude"].isna()
)

# %%
df_sold_new["zero_coords_flag"] = (
    (df_sold_new["Latitude"] == 0) | (df_sold_new["Longitude"] == 0)
)

df_listing_new["zero_coords_flag"] = (
    (df_listing_new["Latitude"] == 0) | (df_listing_new["Longitude"] == 0)
)

# %%
df_sold_new["positive_longitude_flag"] = df_sold_new["Longitude"] > 0
df_listing_new["positive_longitude_flag"] = df_listing_new["Longitude"] > 0

# %%
df_sold_new["out_of_bounds_flag"] = (
    (df_sold_new["Latitude"] < 32) | (df_sold_new["Latitude"] > 42) |
    (df_sold_new["Longitude"] < -125) | (df_sold_new["Longitude"] > -114)
)

df_listing_new["out_of_bounds_flag"] = (
    (df_listing_new["Latitude"] < 32) | (df_listing_new["Latitude"] > 42) |
    (df_listing_new["Longitude"] < -125) | (df_listing_new["Longitude"] > -114)
)

# %%
# sanity check 
# renaming the data sets to simpler names 
sold = df_sold_new.copy()
listing = df_listing_new.copy()

# %%
# Data of sold residential houses after cleaning 
sold
# Out:
#            BuyerAgentAOR      ListAgentAOR           Flooring ViewYN  \
# 0                Arcadia           Arcadia                NaN  False
# 7       CaliforniaDesert  CaliforniaDesert               Tile   True
# 8                 Laguna            Laguna               Wood   True
# 9       PacificSouthwest  PacificSouthwest                NaN   True
# 10      TheInlandGateway  TheInlandGateway  Carpet,Stone,Tile   True
# ...                  ...               ...                ...    ...
# 580369        LakeCounty        LakeCounty                NaN   True
# 580371  TheInlandGateway  TheInlandGateway   Carpet,Tile,Wood  False
# 580374          SanDiego       TriCounties              Vinyl   True
# 580375             Mrmls      OrangeCounty                NaN   True
# 580382         Southland       PacificWest       Carpet,Vinyl  False
#
#        WaterfrontYN BasementYN PoolPrivateYN  OriginalListPrice  ListingKey  \
# 0               NaN        NaN         False          1,130,000   538338723
# 7               NaN        NaN          True          1,995,000  1089077716
# 8               NaN        NaN          True          2,340,000  1089076111
# 9               NaN        NaN          True            984,000  1089075731
# 10              NaN        NaN         False          1,250,000  1089075621
# ...             ...        ...           ...                ...         ...
# 580369          NaN       True         False            279,000  1069708148
# 580371          NaN       True         False            449,000  1067010583
# 580374          NaN        NaN         False          1,579,000  1063196193
# 580375          NaN        NaN         False            855,000  1062106215
# 580382          NaN        NaN         False            375,000  1052387780
#
#                         ListAgentEmail  ... close_day  above_list  \
# 0                  espi.bagwell@kw.com  ...        12       False
# 7              john@johnbomgardner.com  ...        30       False
# 8          andrea@ballesterosgroup.com  ...        30       False
# 9       Cindy@kellemsrealtyproject.com  ...        30       False
# 10                 lynnw@loislauer.com  ...        30       False
# ...                                ...  ...       ...         ...
# 580369     jessica.homesells@gmail.com  ...         1       False
# 580371          brian@cohen-realty.com  ...        13       False
# 580374               info@homecoin.com  ...        16       False
# 580375            jefflachef@gmail.com  ...        16       False
# 580382      elizabethoryan04@gmail.com  ...        24        True
#
#        built_after_sale year_month  purchase_after_close_flag  \
# 0                 False    2024-09                      False
# 7                 False    2024-09                      False
# 8                 False    2024-09                      False
# 9                 False    2024-09                      False
# 10                False    2024-09                      False
# ...                 ...        ...                        ...
# 580369            False    2026-04                      False
# 580371            False    2026-04                      False
# 580374            False    2026-04                      False
# 580375            False    2026-04                      False
# 580382            False    2026-04                      False
#
#         negative_timeline_flag missing_coords_flag zero_coords_flag  \
# 0                        False               False            False
# 7                        False               False            False
# 8                        False               False            False
# 9                        False               False            False
# 10                       False               False            False
# ...                        ...                 ...              ...
# 580369                   False               False            False
# 580371                   False               False            False
# 580374                   False               False            False
# 580375                   False               False            False
# 580382                   False               False            False
#
#         positive_longitude_flag  out_of_bounds_flag
# 0                         False               False
# 7                         False               False
# 8                         False               False
# 9                         False               False
# 10                        False               False
# ...                         ...                 ...
# 580369                    False               False
# 580371                    False               False
# 580374                    False               False
# 580375                    False               False
# 580382                    False               False
#
# [390596 rows x 99 columns]

# %%
# Data of listings of residential houses after cleaning 
listing
# Out:
#         OriginalListPrice  ListingKey                 ListAgentEmail  \
# 0                 569,000  1159577837      drad4realestate@gmail.com
# 1                 878,000  1159577818  catherinerealestate@gmail.com
# 3                 850,000  1159577050     christine.akka@compass.com
# 5                 759,999  1159576072    sally.abdelshahed@gmail.com
# 6               1,995,000  1159576069       alexis@alexisestates.com
# ...                   ...         ...                            ...
# 139237          5,750,000  1151417547                            NaN
# 139238            475,000  1150815309                            NaN
# 139240            825,000  1148377048                            NaN
# 139241          2,849,000  1145743715                            NaN
# 139242          1,649,000  1139631172                            NaN
#
#        CloseDate  ClosePrice ListAgentFirstName ListAgentLastName  Latitude  \
# 0            NaT         NaN           Danielle       Siani-Rader        34
# 1            NaT         NaN          Catherine             Duong        33
# 3            NaT         NaN          Christine              Akka        33
# 5            NaT         NaN              Sally       Abdelshahed        34
# 6            NaT         NaN             Alexis    Boris Waterman        34
# ...          ...         ...                ...               ...       ...
# 139237       NaT         NaN           Jennifer           Okhovat        34
# 139238       NaT         NaN            Melissa             Sofia        33
# 139240       NaT         NaN            Adriana             Gliha        33
# 139241       NaT         NaN               Lori           Barnett        33
# 139242       NaT         NaN             George          Wood Jr.        33
#
#         Longitude             UnparsedAddress  ... close_month  close_day  \
# 0            -116   69707 Northhampton Avenue  ...         NaN        NaN
# 1            -117        200 River Rock Court  ...         NaN        NaN
# 3            -117              1826 Priest St  ...         NaN        NaN
# 5            -118  2886 Villa Catalonia Court  ...         NaN        NaN
# 6            -118    1522 S Point View Street  ...         NaN        NaN
# ...           ...                         ...  ...         ...        ...
# 139237       -118         8732 Rangely Avenue  ...         NaN        NaN
# 139238       -117      4600 lamont street 226  ...         NaN        NaN
# 139240       -117      1461 Fieldbrook Street  ...         NaN        NaN
# 139241       -117       1005 Canvasback Drive  ...         NaN        NaN
# 139242       -117          943 Georgia Street  ...         NaN        NaN
#
#         above_list  year_month purchase_after_close_flag  \
# 0            False     2026-04                     False
# 1            False     2026-04                     False
# 3            False     2026-04                     False
# 5            False     2026-04                     False
# 6            False     2026-04                     False
# ...            ...         ...                       ...
# 139237       False     2026-03                     False
# 139238       False     2026-03                     False
# 139240       False     2026-03                     False
# 139241       False     2026-03                     False
# 139242       False     2026-03                     False
#
#        negative_timeline_flag missing_coords_flag zero_coords_flag  \
# 0                       False               False            False
# 1                       False               False            False
# 3                       False               False            False
# 5                       False               False            False
# 6                       False               False            False
# ...                       ...                 ...              ...
# 139237                  False               False            False
# 139238                  False               False            False
# 139240                  False               False            False
# 139241                  False               False            False
# 139242                  False               False            False
#
#        positive_longitude_flag out_of_bounds_flag
# 0                        False              False
# 1                        False              False
# 3                        False              False
# 5                        False              False
# 6                        False              False
# ...                        ...                ...
# 139237                   False              False
# 139238                   False              False
# 139240                   False              False
# 139241                   False              False
# 139242                   False              False
#
# [81332 rows x 96 columns]

# %% [markdown]
# # Week 6
# ## Feature Engineering and Market Metrics.

# %% [markdown]
# #### After cleaning our data and accounting for missing values, invalid values and variables, we can start with creating key metrics for feature engineering for our data.

# %% [markdown]
# ### 1) Price Ratio
# #### price ratio = close price / original list price. Mesearing the negotiation strength.
# #### higher ratio = higher close price = less negotiation rate.
# #### lower ratio = higher list price = higher negotiation rate.

# %%
import numpy as np
sold["Price_Ratio"] = sold["ClosePrice"]/sold["OriginalListPrice"]
sold["Price_Ratio"].describe()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# count   389,891
# mean        inf
# std         NaN
# min           0
# 25%           1
# 50%           1
# 75%           1
# max         inf
# Name: Price_Ratio, dtype: float64

# %%
# Replace inf and -inf with NaN
sold["Price_Ratio"] = sold["Price_Ratio"].replace([np.inf, -np.inf], np.nan)

# Drop missing values
sold = sold.dropna(subset=["Price_Ratio"])

# Remove extreme 1% tails
lower = sold["Price_Ratio"].quantile(0.01)
upper = sold["Price_Ratio"].quantile(0.99)

sold = sold[
    (sold["Price_Ratio"] >= lower) &
    (sold["Price_Ratio"] <= upper)
]

# Check results
sold["Price_Ratio"].describe()
# Out:
# count   382,091
# mean          1
# std           0
# min           1
# 25%           1
# 50%           1
# 75%           1
# max           1
# Name: Price_Ratio, dtype: float64

# %% [markdown]
# ### 2) Price Per Square Feet
# #### close price /living area
# #### normalizes prize across sizes of land
# higher ratio = higher price per square feet of land
#
# lower ratio = lower price per square feet of land

# %%
sold["Price_per_sqrft"] = sold["ClosePrice"]/ sold["LivingArea"]
sold["Price_per_sqrft"].describe()
# Out:
# count   381,886
# mean        607
# std       1,851
# min           0
# 25%         370
# 50%         538
# 75%         731
# max     735,000
# Name: Price_per_sqrft, dtype: float64

# %%
sold = sold.dropna(subset=["Price_per_sqrft"])

# Remove 1% outliers on both ends
lower = sold["Price_per_sqrft"].quantile(0.01)
upper = sold["Price_per_sqrft"].quantile(0.99)

sold = sold[
    (sold["Price_per_sqrft"] >= lower) &
    (sold["Price_per_sqrft"] <= upper)
]

# Check new summary
sold["Price_per_sqrft"].describe()
# Out:
# count   374,248
# mean        587
# std         287
# min         169
# 25%         374
# 50%         538
# 75%         725
# max       1,854
# Name: Price_per_sqrft, dtype: float64

# %% [markdown]
# ## 3) Price reduction history
# #### 1 - Close price / Original list price
# Higher ratio = seller reduced price more from original asking price.
#
# Lower ratio = home sold near original asking price, suggesting stronger pricing accuracy or demand.

# %%
sold["Discount_Ratio"] = 1-(sold["ClosePrice"]/sold["OriginalListPrice"])
sold["Discount_Ratio"].describe()
# Out:
# count   374,248
# mean          0
# std           0
# min          -0
# 25%          -0
# 50%           0
# 75%           0
# max           0
# Name: Discount_Ratio, dtype: float64

# %%
# Remove inf values
sold["Discount_Ratio"] = sold["Discount_Ratio"].replace(
    [np.inf, -np.inf],
    np.nan
)

# Drop missing values
sold = sold.dropna(subset=["Discount_Ratio"])

# Remove extreme 1% tails
lower = sold["Discount_Ratio"].quantile(0.01)
upper = sold["Discount_Ratio"].quantile(0.99)

sold = sold[
    (sold["Discount_Ratio"] >= lower) &
    (sold["Discount_Ratio"] <= upper)
]

# Summary
sold["Discount_Ratio"].describe()
# Out:
# count   366,769
# mean          0
# std           0
# min          -0
# 25%          -0
# 50%           0
# 75%           0
# max           0
# Name: Discount_Ratio, dtype: float64

# %% [markdown]
# ## 4) Listing to Contract Days
# #### Purchse Contract date - Listing contract date
# Measures time between the listing to the accepted offer

# %%
sold["Listing_to_contract"] = (
    sold["PurchaseContractDate"] - sold["ListingContractDate"]
).dt.days
sold["Listing_to_contract"].describe()
# Out:
# count   366,585
# mean         42
# std          82
# min     -36,407
# 25%          10
# 50%          24
# 75%          55
# max       7,325
# Name: Listing_to_contract, dtype: float64

# %%
sold = sold[sold["Listing_to_contract"] >= 0]

# Remove extreme outliers (top 1%)
upper = sold["Listing_to_contract"].quantile(0.99)

sold = sold[sold["Listing_to_contract"] <= upper]

# Summary
sold["Listing_to_contract"].describe()
# Out:
# count   362,769
# mean         40
# std          42
# min           0
# 25%          10
# 50%          24
# 75%          54
# max         248
# Name: Listing_to_contract, dtype: float64

# %% [markdown]
# ## 5)  Contract to Close date
# #### Close Date - Purchanse Contract date.

# %%
sold["contract_to_close"] = (sold["CloseDate"] - sold["PurchaseContractDate"]).dt.days
sold["contract_to_close"].describe()
# Out:
# count   362,769
# mean         31
# std          23
# min         -61
# 25%          21
# 50%          29
# 75%          36
# max       1,816
# Name: contract_to_close, dtype: float64

# %%
# Remove negatives
sold = sold[sold["contract_to_close"] >= 0]

# Remove top 1%
upper = sold["contract_to_close"].quantile(0.99)

sold = sold[sold["contract_to_close"] <= upper]

# Summary
sold["contract_to_close"].describe()
# Out:
# count   359,145
# mean         30
# std          16
# min           0
# 25%          21
# 50%          29
# 75%          36
# max         111
# Name: contract_to_close, dtype: float64

# %% [markdown]
# Some ratio-based metrics contained infinite, zero, negative, or extremely large values caused by missing data, division by zero, and inconsistent property records. Invalid observations and extreme outliers were removed using percentile-based trimming to improve the reliability and interpretability of the engineered features.

# %%
metrics = [
    "Price_Ratio",
    "Price_per_sqrft",
    "Discount_Ratio",
    "Listing_to_contract",
    "contract_to_close",
    "DaysOnMarket",
    "ClosePrice"
]

# %%
# =========================================================
# 1) Property Type / Subtype Analysis
# =========================================================

propertytype_summary = (
    sold.groupby("PropertyType")[metrics]
    .agg(["count", "mean", "median"])
    .round(2)
)

propertysubtype_summary = (sold.groupby("PropertySubType")[metrics]
    .agg(["count", "mean", "median"])
    .round(2)
)

display(propertytype_summary.head())
display(propertysubtype_summary.head())


# =========================================================
# 2) Geographic Segment Analysis
# =========================================================

county_summary = (
    sold.groupby("CountyOrParish")[metrics]
    .agg(["count", "mean", "median"])
    .round(2)
)

mlsarea_summary = (
    sold.groupby("MLSAreaMajor")[metrics]
    .agg(["count", "mean", "median"])
    .round(2)
)

display(county_summary.head())
display(mlsarea_summary.head())


# =========================================================
# 3) Brokerage / Office Competitive Analysis
# =========================================================

listoffice_summary = (sold.groupby("ListOfficeName")[metrics]
    .agg(["count", "mean", "median"])
    .round(2)
    .sort_values(("ClosePrice", "count"), ascending=False)
)

buyeroffice_summary = (
    sold.groupby("BuyerOfficeName")[metrics]
    .agg(["count", "mean", "median"])
    .round(2)
    .sort_values(("ClosePrice", "count"), ascending=False)
)

display(listoffice_summary.head(10))
display(buyeroffice_summary.head(10))
# Out:
#              Price_Ratio             Price_per_sqrft              \
#                    count mean median           count mean median
# PropertyType
# Residential       359145    1      1          359145  586    538
#
#              Discount_Ratio             Listing_to_contract  ...         \
#                       count mean median               count  ... median
# PropertyType                                                 ...
# Residential          359145    0      0              359145  ...     24
#
#              contract_to_close             DaysOnMarket              \
#                          count mean median        count mean median
# PropertyType
# Residential             359145   30     29       359145   33     18
#
#              ClosePrice
#                   count      mean  median
# PropertyType
# Residential      359145 1,079,906 820,000
#
# [1 rows x 21 columns]
#                 Price_Ratio             Price_per_sqrft               \
#                       count mean median           count  mean median
# PropertySubType
# BoatSlip                 22    1      1              22 1,463  1,550
# Cabin                   276    1      1             276   368    335
# CoOwnership              13    1      1              13   438    434
# Condominium           61121    1      1           61121   596    568
# DeededParking             3    1      1               3   414    296
#
#                 Discount_Ratio             Listing_to_contract  ...         \
#                          count mean median               count  ... median
# PropertySubType                                                 ...
# BoatSlip                    22    0      0                  22  ...     18
# Cabin                      276    0      0                 276  ...     37
# CoOwnership                 13    0      0                  13  ...     21
# Condominium              61121    0      0               61121  ...     28
# DeededParking                3   -0     -0                   3  ...     31
#
#                 contract_to_close             DaysOnMarket              \
#                             count mean median        count mean median
# PropertySubType
# BoatSlip                       22   20     17           22   34     18
# Cabin                         276   33     31          276   50     29
# CoOwnership                    13   37     38           13   34     17
# Condominium                 61121   29     28        61121   38     23
# DeededParking                   3   19     23            3   33     29
#
#                 ClosePrice
#                      count    mean  median
# PropertySubType
# BoatSlip                22 175,586 162,500
# Cabin                  276 347,235 294,000
# CoOwnership             13 530,808 400,000
# Condominium          61121 741,780 628,000
# DeededParking            3 700,000 630,000
#
# [5 rows x 21 columns]
#                Price_Ratio             Price_per_sqrft              \
#                      count mean median           count mean median
# CountyOrParish
# Alameda              15959    1      1           15959  717    688
# Amador                  13    1      1              13  274    283
# Butte                 3240    1      1            3240  280    279
# Calaveras               67    1      1              67  309    285
# Clark                    1    1      1               1  286    286
#
#                Discount_Ratio             Listing_to_contract  ...         \
#                         count mean median               count  ... median
# CountyOrParish                                                 ...
# Alameda                 15959   -0     -0               15959  ...     14
# Amador                     13    0      0                  13  ...     40
# Butte                    3240    0      0                3240  ...     26
# Calaveras                  67    0      0                  67  ...     46
# Clark                       1    0      0                   1  ...      2
#
#                contract_to_close             DaysOnMarket              \
#                            count mean median        count mean median
# CountyOrParish
# Alameda                    15959   25     24        15959   25     14
# Amador                        13   34     30           13   71     40
# Butte                       3240   32     30         3240   40     19
# Calaveras                     67   31     29           67   54     45
# Clark                          1    9      9            1    2      2
#
#                ClosePrice
#                     count      mean    median
# CountyOrParish
# Alameda             15959 1,227,626 1,065,000
# Amador                 13   502,857   499,000
# Butte                3240   457,679   420,000
# Calaveras              67   613,702   515,000
# Clark                   1   375,000   375,000
#
# [5 rows x 21 columns]
#                                                   Price_Ratio              \
#                                                         count mean median
# MLSAreaMajor
# 1 - Belmont Shore/Park,Naples,Marina Pac,Bay Hrbr         393    1      1
# 101 - North Inglewood                                     327    1      1
# 102 - South Inglewood                                     124    1      1
# 103 - Ladera Heights                                      104    1      1
# 105 - Lennox                                               20    1      1
#
#                                                   Price_per_sqrft              \
#                                                             count mean median
# MLSAreaMajor
# 1 - Belmont Shore/Park,Naples,Marina Pac,Bay Hrbr             393  848    780
# 101 - North Inglewood                                         327  548    504
# 102 - South Inglewood                                         124  573    558
# 103 - Ladera Heights                                          104  666    655
# 105 - Lennox                                                   20  583    555
#
#                                                   Discount_Ratio              \
#                                                            count mean median
# MLSAreaMajor
# 1 - Belmont Shore/Park,Naples,Marina Pac,Bay Hrbr            393    0      0
# 101 - North Inglewood                                        327    0      0
# 102 - South Inglewood                                        124    0      0
# 103 - Ladera Heights                                         104    0      0
# 105 - Lennox                                                  20    0      0
#
#                                                   Listing_to_contract  ...  \
#                                                                 count  ...
# MLSAreaMajor                                                           ...
# 1 - Belmont Shore/Park,Naples,Marina Pac,Bay Hrbr                 393  ...
# 101 - North Inglewood                                             327  ...
# 102 - South Inglewood                                             124  ...
# 103 - Ladera Heights                                              104  ...
# 105 - Lennox                                                       20  ...
#
#                                                          contract_to_close  \
#                                                   median             count
# MLSAreaMajor
# 1 - Belmont Shore/Park,Naples,Marina Pac,Bay Hrbr     27               393
# 101 - North Inglewood                                 38               327
# 102 - South Inglewood                                 35               124
# 103 - Ladera Heights                                  28               104
# 105 - Lennox                                          54                20
#
#                                                               DaysOnMarket  \
#                                                   mean median        count
# MLSAreaMajor
# 1 - Belmont Shore/Park,Naples,Marina Pac,Bay Hrbr   31     29          393
# 101 - North Inglewood                               38     34          327
# 102 - South Inglewood                               35     33          124
# 103 - Ladera Heights                                32     30          104
# 105 - Lennox                                        37     38           20
#
#                                                               ClosePrice  \
#                                                   mean median      count
# MLSAreaMajor
# 1 - Belmont Shore/Park,Naples,Marina Pac,Bay Hrbr   34     15        393
# 101 - North Inglewood                               45     29        327
# 102 - South Inglewood                               41     24        124
# 103 - Ladera Heights                                48     27        104
# 105 - Lennox                                        52     31         20
#
#
#                                                        mean    median
# MLSAreaMajor
# 1 - Belmont Shore/Park,Naples,Marina Pac,Bay Hrbr 1,514,220 1,349,900
# 101 - North Inglewood                               710,205   675,000
# 102 - South Inglewood                               801,458   790,000
# 103 - Ladera Heights                              1,747,516 1,697,500
# 105 - Lennox                                        686,950   700,000
#
# [5 rows x 21 columns]
#                                                    Price_Ratio              \
#                                                          count mean median
# ListOfficeName
# Compass                                                  24738    1      1
# Coldwell Banker Realty                                   16106    1      1
# Keller Williams Realty                                    7268    1      1
# First Team Real Estate                                    5234    1      1
# Berkshire Hathaway HomeServices California Prop...        4794    1      1
# eXp Realty of California Inc                              4208    1      1
# Real Broker                                               4197    1      1
# Intero Real Estate Services                               3824    1      1
# eXp Realty of California, Inc.                            3213    1      1
# Equity Union                                              3086    1      1
#
#                                                    Price_per_sqrft       \
#                                                              count mean
# ListOfficeName
# Compass                                                      24738  793
# Coldwell Banker Realty                                       16106  738
# Keller Williams Realty                                        7268  564
# First Team Real Estate                                        5234  614
# Berkshire Hathaway HomeServices California Prop...            4794  653
# eXp Realty of California Inc                                  4208  575
# Real Broker                                                   4197  583
# Intero Real Estate Services                                   3824  856
# eXp Realty of California, Inc.                                3213  538
# Equity Union                                                  3086  522
#
#                                                           Discount_Ratio       \
#                                                    median          count mean
# ListOfficeName
# Compass                                               739          24738    0
# Coldwell Banker Realty                                682          16106    0
# Keller Williams Realty                                542           7268    0
# First Team Real Estate                                610           5234    0
# Berkshire Hathaway HomeServices California Prop...    591           4794    0
# eXp Realty of California Inc                          537           4208    0
# Real Broker                                           560           4197    0
# Intero Real Estate Services                           808           3824   -0
# eXp Realty of California, Inc.                        499           3213   -0
# Equity Union                                          483           3086    0
#
#                                                           Listing_to_contract  \
#                                                    median               count
# ListOfficeName
# Compass                                                 0               24738
# Coldwell Banker Realty                                  0               16106
# Keller Williams Realty                                  0                7268
# First Team Real Estate                                  0                5234
# Berkshire Hathaway HomeServices California Prop...      0                4794
# eXp Realty of California Inc                            0                4208
# Real Broker                                             0                4197
# Intero Real Estate Services                            -0                3824
# eXp Realty of California, Inc.                          0                3213
# Equity Union                                            0                3086
#
#                                                     ...         \
#                                                     ... median
# ListOfficeName                                      ...
# Compass                                             ...     18
# Coldwell Banker Realty                              ...     21
# Keller Williams Realty                              ...     21
# First Team Real Estate                              ...     25
# Berkshire Hathaway HomeServices California Prop...  ...     27
# eXp Realty of California Inc                        ...     24
# Real Broker                                         ...     23
# Intero Real Estate Services                         ...     12
# eXp Realty of California, Inc.                      ...     21
# Equity Union                                        ...     31
#
#                                                    contract_to_close       \
#                                                                count mean
# ListOfficeName
# Compass                                                        24738   26
# Coldwell Banker Realty                                         16106   26
# Keller Williams Realty                                          7268   29
# First Team Real Estate                                          5234   30
# Berkshire Hathaway HomeServices California Prop...              4794   28
# eXp Realty of California Inc                                    4208   31
# Real Broker                                                     4197   29
# Intero Real Estate Services                                     3824   26
# eXp Realty of California, Inc.                                  3213   29
# Equity Union                                                    3086   26
#
#                                                           DaysOnMarket       \
#                                                    median        count mean
# ListOfficeName
# Compass                                                25        24738   28
# Coldwell Banker Realty                                 26        16106   31
# Keller Williams Realty                                 28         7268   29
# First Team Real Estate                                 29         5234   26
# Berkshire Hathaway HomeServices California Prop...     28         4794   37
# eXp Realty of California Inc                           29         4208   33
# Real Broker                                            27         4197   27
# Intero Real Estate Services                            25         3824   24
# eXp Realty of California, Inc.                         27         3213   26
# Equity Union                                           26         3086   42
#
#                                                           ClosePrice  \
#                                                    median      count
# ListOfficeName
# Compass                                                14      24738
# Coldwell Banker Realty                                 15      16106
# Keller Williams Realty                                 14       7268
# First Team Real Estate                                 12       5234
# Berkshire Hathaway HomeServices California Prop...     22       4794
# eXp Realty of California Inc                           18       4208
# Real Broker                                            14       4197
# Intero Real Estate Services                            12       3824
# eXp Realty of California, Inc.                         13       3213
# Equity Union                                           27       3086
#
#
#                                                         mean    median
# ListOfficeName
# Compass                                            1,646,026 1,300,000
# Coldwell Banker Realty                             1,455,651 1,150,000
# Keller Williams Realty                             1,015,862   864,995
# First Team Real Estate                             1,108,393   960,000
# Berkshire Hathaway HomeServices California Prop... 1,328,983   925,000
# eXp Realty of California Inc                         967,240   790,500
# Real Broker                                        1,046,444   840,000
# Intero Real Estate Services                        1,530,731 1,300,000
# eXp Realty of California, Inc.                       929,933   765,000
# Equity Union                                       1,063,551   865,000
#
# [10 rows x 21 columns]
#                                                    Price_Ratio              \
#                                                          count mean median
# BuyerOfficeName
# Compass                                                  23037    1      1
# Coldwell Banker Realty                                   12880    1      1
# NONMEMBER MRML                                            7145    1      1
# Keller Williams Realty                                    5649    1      1
# Real Broker                                               5523    1      1
# eXp Realty of California Inc                              4711    1      1
# First Team Real Estate                                    4711    1      1
# eXp Realty of California, Inc.                            4203    1      1
# Berkshire Hathaway HomeServices California Prop...        3753    1      1
# Intero Real Estate Services                               3151    1      1
#
#                                                    Price_per_sqrft       \
#                                                              count mean
# BuyerOfficeName
# Compass                                                      23037  791
# Coldwell Banker Realty                                       12880  734
# NONMEMBER MRML                                                7145  361
# Keller Williams Realty                                        5649  558
# Real Broker                                                   5523  574
# eXp Realty of California Inc                                  4711  610
# First Team Real Estate                                        4711  604
# eXp Realty of California, Inc.                                4203  530
# Berkshire Hathaway HomeServices California Prop...            3753  662
# Intero Real Estate Services                                   3151  839
#
#                                                           Discount_Ratio       \
#                                                    median          count mean
# BuyerOfficeName
# Compass                                               734          23037    0
# Coldwell Banker Realty                                678          12880    0
# NONMEMBER MRML                                        296           7145    0
# Keller Williams Realty                                535           5649    0
# Real Broker                                           544           5523    0
# eXp Realty of California Inc                          574           4711    0
# First Team Real Estate                                598           4711    0
# eXp Realty of California, Inc.                        497           4203    0
# Berkshire Hathaway HomeServices California Prop...    599           3753    0
# Intero Real Estate Services                           797           3151   -0
#
#                                                           Listing_to_contract  \
#                                                    median               count
# BuyerOfficeName
# Compass                                                 0               23037
# Coldwell Banker Realty                                  0               12880
# NONMEMBER MRML                                          0                7145
# Keller Williams Realty                                  0                5649
# Real Broker                                             0                5523
# eXp Realty of California Inc                            0                4711
# First Team Real Estate                                  0                4711
# eXp Realty of California, Inc.                          0                4203
# Berkshire Hathaway HomeServices California Prop...      0                3753
# Intero Real Estate Services                            -0                3151
#
#                                                     ...         \
#                                                     ... median
# BuyerOfficeName                                     ...
# Compass                                             ...     18
# Coldwell Banker Realty                              ...     21
# NONMEMBER MRML                                      ...     30
# Keller Williams Realty                              ...     22
# Real Broker                                         ...     25
# eXp Realty of California Inc                        ...     24
# First Team Real Estate                              ...     23
# eXp Realty of California, Inc.                      ...     25
# Berkshire Hathaway HomeServices California Prop...  ...     26
# Intero Real Estate Services                         ...     12
#
#                                                    contract_to_close       \
#                                                                count mean
# BuyerOfficeName
# Compass                                                        23037   26
# Coldwell Banker Realty                                         12880   27
# NONMEMBER MRML                                                  7145   34
# Keller Williams Realty                                          5649   28
# Real Broker                                                     5523   29
# eXp Realty of California Inc                                    4711   29
# First Team Real Estate                                          4711   29
# eXp Realty of California, Inc.                                  4203   29
# Berkshire Hathaway HomeServices California Prop...              3753   28
# Intero Real Estate Services                                     3151   26
#
#                                                           DaysOnMarket       \
#                                                    median        count mean
# BuyerOfficeName
# Compass                                                25        23037   30
# Coldwell Banker Realty                                 26        12880   31
# NONMEMBER MRML                                         31         7145   39
# Keller Williams Realty                                 27         5649   31
# Real Broker                                            27         5523   31
# eXp Realty of California Inc                           28         4711   33
# First Team Real Estate                                 28         4711   28
# eXp Realty of California, Inc.                         27         4203   32
# Berkshire Hathaway HomeServices California Prop...     28         3753   36
# Intero Real Estate Services                            25         3151   24
#
#                                                           ClosePrice  \
#                                                    median      count
# BuyerOfficeName
# Compass                                                15      23037
# Coldwell Banker Realty                                 15      12880
# NONMEMBER MRML                                         23       7145
# Keller Williams Realty                                 16       5649
# Real Broker                                            17       5523
# eXp Realty of California Inc                           18       4711
# First Team Real Estate                                 13       4711
# eXp Realty of California, Inc.                         17       4203
# Berkshire Hathaway HomeServices California Prop...     20       3753
# Intero Real Estate Services                            12       3151
#
#
#                                                         mean    median
# BuyerOfficeName
# Compass                                            1,624,015 1,279,000
# Coldwell Banker Realty                             1,444,350 1,150,000
# NONMEMBER MRML                                       629,729   512,000
# Keller Williams Realty                             1,016,193   830,000
# Real Broker                                          989,063   800,000
# eXp Realty of California Inc                       1,023,597   835,000
# First Team Real Estate                             1,058,209   900,000
# eXp Realty of California, Inc.                       871,187   731,600
# Berkshire Hathaway HomeServices California Prop... 1,352,172   945,000
# Intero Real Estate Services                        1,497,116 1,290,000
#
# [10 rows x 21 columns]

# %% [markdown]
# # Week 7
# ### Using IQR method to remove outliers in price, square foot, and days on market.

# %%
cols = ['ClosePrice', 'LotSizeSquareFeet', 'DaysOnMarket']

Q1 = sold[cols].quantile(0.25)
Q3 = sold[cols].quantile(0.75)

print(Q1)
print(Q3)

IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR
# Out:
# ClosePrice          583,000
# LotSizeSquareFeet     5,227
# DaysOnMarket              8
# Name: 0.25, dtype: float64
# ClosePrice          1,270,000
# LotSizeSquareFeet      11,627
# DaysOnMarket               45
# Name: 0.75, dtype: float64

# %%
sold["days_on_market_flag"] = ( (sold["DaysOnMarket"] <= Q1["DaysOnMarket"]) | (sold["DaysOnMarket"] >= Q3["DaysOnMarket"]))

sold["SQR_feet_flag"] = ((sold["LotSizeSquareFeet"] <= Q1["LotSizeSquareFeet"]) | (sold["LotSizeSquareFeet"] >= Q3["LotSizeSquareFeet"]))

sold["Close_price_flag"] = ((sold["ClosePrice"] <= Q1["ClosePrice"]) | (sold["ClosePrice"] >= Q3["ClosePrice"]))

# %%
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR
clean_sold = sold[
    (sold['ClosePrice'] >= lower['ClosePrice']) &
    (sold['ClosePrice'] <= upper['ClosePrice']) &
    (sold['DaysOnMarket'] >= lower['DaysOnMarket']) &
    (sold['DaysOnMarket'] <= upper['DaysOnMarket']) &
    (sold['LotSizeSquareFeet'] >= lower['LotSizeSquareFeet']) &
    (sold['LotSizeSquareFeet'] <= upper['LotSizeSquareFeet'])
]

# %%
clean_sold
# Out:
#                 BuyerAgentAOR           ListAgentAOR           Flooring  \
# 7            CaliforniaDesert       CaliforniaDesert               Tile
# 9            PacificSouthwest       PacificSouthwest                NaN
# 10           TheInlandGateway       TheInlandGateway  Carpet,Stone,Tile
# 11                PacificWest            PacificWest                NaN
# 12      BeverlyHillsGreaterLa  BeverlyHillsGreaterLa                NaN
# ...                       ...                    ...                ...
# 579673                    NaN         VenturaCoastal        Carpet,Wood
# 579684      PasadenaFoothills              Southland                NaN
# 579759  BeverlyHillsGreaterLa         OutOfAreaBoard                NaN
# 579802              Southland              Southland                NaN
# 579823              Southland                Burbank           Laminate
#
#        ViewYN WaterfrontYN BasementYN PoolPrivateYN  OriginalListPrice  \
# 7        True          NaN        NaN          True          1,995,000
# 9        True          NaN        NaN          True            984,000
# 10       True          NaN        NaN         False          1,250,000
# 11       True          NaN        NaN         False            910,000
# 12      False          NaN        NaN         False          1,849,000
# ...       ...          ...        ...           ...                ...
# 579673  False          NaN        NaN          True          2,009,000
# 579684   True          NaN        NaN         False            680,000
# 579759  False          NaN        NaN         False          1,699,000
# 579802  False          NaN        NaN         False          1,150,000
# 579823   True          NaN        NaN         False            995,000
#
#         ListingKey                  ListAgentEmail  ...  \
# 7       1089077716         john@johnbomgardner.com  ...
# 9       1089075731  Cindy@kellemsrealtyproject.com  ...
# 10      1089075621             lynnw@loislauer.com  ...
# 11      1089075009       Lorifennrealtor@gmail.com  ...
# 12      1089074282      hello@stephanieyounger.com  ...
# ...            ...                             ...  ...
# 579673  1120127517             constinab@gmail.com  ...
# 579684  1120060298   johnathan@mycherishedhome.com  ...
# 579759  1119591646              sierus@truline.com  ...
# 579802  1119015999          Cherrie.Zach@Gmail.Com  ...
# 579823  1118923053   schaedlerrealestate@gmail.com  ...
#
#        positive_longitude_flag  out_of_bounds_flag Price_Ratio  \
# 7                        False               False           1
# 9                        False               False           1
# 10                       False               False           1
# 11                       False               False           1
# 12                       False               False           1
# ...                        ...                 ...         ...
# 579673                   False               False           1
# 579684                   False               False           1
# 579759                   False               False           1
# 579802                   False               False           1
# 579823                   False               False           1
#
#        Price_per_sqrft  Discount_Ratio  Listing_to_contract contract_to_close  \
# 7                  566               0                    0                 0
# 9                  626               0                    1                30
# 10                 424               0                    7                52
# 11                 552               0                   13                 0
# 12                 980               0                    0                 0
# ...                ...             ...                  ...               ...
# 579673             728               0                  192                62
# 579684             547              -0                  223                31
# 579759             617               0                  233                31
# 579802             732               0                  231                56
# 579823             515               0                  221                49
#
#        days_on_market_flag  SQR_feet_flag  Close_price_flag
# 7                     True           True              True
# 9                     True          False             False
# 10                    True          False             False
# 11                    True          False             False
# 12                    True          False              True
# ...                    ...            ...               ...
# 579673                True          False              True
# 579684               False           True             False
# 579759               False          False              True
# 579802               False          False             False
# 579823                True           True             False
#
# [243866 rows x 107 columns]

# %%
df_sold_week7= clean_sold[
    (clean_sold['DaysOnMarket'] >= lower['DaysOnMarket']) &
    (clean_sold['DaysOnMarket'] <= upper['DaysOnMarket']) &

    (clean_sold['LotSizeSquareFeet'] >= lower['LotSizeSquareFeet']) &
    (clean_sold['LotSizeSquareFeet'] <= upper['LotSizeSquareFeet']) &

    (clean_sold['ClosePrice'] >= lower['ClosePrice']) &
    (clean_sold['ClosePrice'] <= upper['ClosePrice'])
]

# %%
df_sold_week7
# Out:
#                 BuyerAgentAOR           ListAgentAOR           Flooring  \
# 7            CaliforniaDesert       CaliforniaDesert               Tile
# 9            PacificSouthwest       PacificSouthwest                NaN
# 10           TheInlandGateway       TheInlandGateway  Carpet,Stone,Tile
# 11                PacificWest            PacificWest                NaN
# 12      BeverlyHillsGreaterLa  BeverlyHillsGreaterLa                NaN
# ...                       ...                    ...                ...
# 579673                    NaN         VenturaCoastal        Carpet,Wood
# 579684      PasadenaFoothills              Southland                NaN
# 579759  BeverlyHillsGreaterLa         OutOfAreaBoard                NaN
# 579802              Southland              Southland                NaN
# 579823              Southland                Burbank           Laminate
#
#        ViewYN WaterfrontYN BasementYN PoolPrivateYN  OriginalListPrice  \
# 7        True          NaN        NaN          True          1,995,000
# 9        True          NaN        NaN          True            984,000
# 10       True          NaN        NaN         False          1,250,000
# 11       True          NaN        NaN         False            910,000
# 12      False          NaN        NaN         False          1,849,000
# ...       ...          ...        ...           ...                ...
# 579673  False          NaN        NaN          True          2,009,000
# 579684   True          NaN        NaN         False            680,000
# 579759  False          NaN        NaN         False          1,699,000
# 579802  False          NaN        NaN         False          1,150,000
# 579823   True          NaN        NaN         False            995,000
#
#         ListingKey                  ListAgentEmail  ...  \
# 7       1089077716         john@johnbomgardner.com  ...
# 9       1089075731  Cindy@kellemsrealtyproject.com  ...
# 10      1089075621             lynnw@loislauer.com  ...
# 11      1089075009       Lorifennrealtor@gmail.com  ...
# 12      1089074282      hello@stephanieyounger.com  ...
# ...            ...                             ...  ...
# 579673  1120127517             constinab@gmail.com  ...
# 579684  1120060298   johnathan@mycherishedhome.com  ...
# 579759  1119591646              sierus@truline.com  ...
# 579802  1119015999          Cherrie.Zach@Gmail.Com  ...
# 579823  1118923053   schaedlerrealestate@gmail.com  ...
#
#        positive_longitude_flag  out_of_bounds_flag Price_Ratio  \
# 7                        False               False           1
# 9                        False               False           1
# 10                       False               False           1
# 11                       False               False           1
# 12                       False               False           1
# ...                        ...                 ...         ...
# 579673                   False               False           1
# 579684                   False               False           1
# 579759                   False               False           1
# 579802                   False               False           1
# 579823                   False               False           1
#
#        Price_per_sqrft  Discount_Ratio  Listing_to_contract contract_to_close  \
# 7                  566               0                    0                 0
# 9                  626               0                    1                30
# 10                 424               0                    7                52
# 11                 552               0                   13                 0
# 12                 980               0                    0                 0
# ...                ...             ...                  ...               ...
# 579673             728               0                  192                62
# 579684             547              -0                  223                31
# 579759             617               0                  233                31
# 579802             732               0                  231                56
# 579823             515               0                  221                49
#
#        days_on_market_flag  SQR_feet_flag  Close_price_flag
# 7                     True           True              True
# 9                     True          False             False
# 10                    True          False             False
# 11                    True          False             False
# 12                    True          False              True
# ...                    ...            ...               ...
# 579673                True          False              True
# 579684               False           True             False
# 579759               False          False              True
# 579802               False          False             False
# 579823                True           True             False
#
# [243866 rows x 107 columns]

# %%
fig, axes = plt.subplots(1, len(cols), figsize=(5 * len(cols), 5))

for i, col in enumerate(cols):
    df_sold_week7[[col]].boxplot(ax=axes[i])
    axes[i].set_title(f"{col}")

fig.suptitle("After Outlier Removal (Week 7)", fontsize=14)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt


fig, axes = plt.subplots(len(cols), 2, figsize=(12, 5 * len(cols)))

for i, col in enumerate(cols):
    sold[[col]].boxplot(ax=axes[i, 0])
    axes[i, 0].set_title(f"{col} — Before")

    df_sold_week7[[col]].boxplot(ax=axes[i, 1])
    axes[i, 1].set_title(f"{col} — After")

plt.tight_layout()
plt.show()

# %%
Q1 = listing[['DaysOnMarket', 'LotSizeSquareFeet', 'ClosePrice']].quantile(0.25)
Q3 = listing[['DaysOnMarket', 'LotSizeSquareFeet', 'ClosePrice']].quantile(0.75)

# %%
listing_clean = listing.copy()
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

listing_clean["flag_DaysOnMarket"] = (
    (listing["DaysOnMarket"] < lower["DaysOnMarket"]) |
    (listing["DaysOnMarket"] > upper["DaysOnMarket"])
)

listing_clean["flag_LotSizeSquareFeet"] = (
    (listing["LotSizeSquareFeet"] < lower["LotSizeSquareFeet"]) |
    (listing["LotSizeSquareFeet"] > upper["LotSizeSquareFeet"])
)

listing_clean["flag_ClosePrice"] = (
    (listing["ClosePrice"] < lower["ClosePrice"]) |
    (listing["ClosePrice"] > upper["ClosePrice"])
)

# %%
listing_clean
# Out:
#         OriginalListPrice  ListingKey                 ListAgentEmail  \
# 0                 569,000  1159577837      drad4realestate@gmail.com
# 1                 878,000  1159577818  catherinerealestate@gmail.com
# 3                 850,000  1159577050     christine.akka@compass.com
# 5                 759,999  1159576072    sally.abdelshahed@gmail.com
# 6               1,995,000  1159576069       alexis@alexisestates.com
# ...                   ...         ...                            ...
# 139237          5,750,000  1151417547                            NaN
# 139238            475,000  1150815309                            NaN
# 139240            825,000  1148377048                            NaN
# 139241          2,849,000  1145743715                            NaN
# 139242          1,649,000  1139631172                            NaN
#
#        CloseDate  ClosePrice ListAgentFirstName ListAgentLastName  Latitude  \
# 0            NaT         NaN           Danielle       Siani-Rader        34
# 1            NaT         NaN          Catherine             Duong        33
# 3            NaT         NaN          Christine              Akka        33
# 5            NaT         NaN              Sally       Abdelshahed        34
# 6            NaT         NaN             Alexis    Boris Waterman        34
# ...          ...         ...                ...               ...       ...
# 139237       NaT         NaN           Jennifer           Okhovat        34
# 139238       NaT         NaN            Melissa             Sofia        33
# 139240       NaT         NaN            Adriana             Gliha        33
# 139241       NaT         NaN               Lori           Barnett        33
# 139242       NaT         NaN             George          Wood Jr.        33
#
#         Longitude             UnparsedAddress  ... year_month  \
# 0            -116   69707 Northhampton Avenue  ...    2026-04
# 1            -117        200 River Rock Court  ...    2026-04
# 3            -117              1826 Priest St  ...    2026-04
# 5            -118  2886 Villa Catalonia Court  ...    2026-04
# 6            -118    1522 S Point View Street  ...    2026-04
# ...           ...                         ...  ...        ...
# 139237       -118         8732 Rangely Avenue  ...    2026-03
# 139238       -117      4600 lamont street 226  ...    2026-03
# 139240       -117      1461 Fieldbrook Street  ...    2026-03
# 139241       -117       1005 Canvasback Drive  ...    2026-03
# 139242       -117          943 Georgia Street  ...    2026-03
#
#         purchase_after_close_flag  negative_timeline_flag  \
# 0                           False                   False
# 1                           False                   False
# 3                           False                   False
# 5                           False                   False
# 6                           False                   False
# ...                           ...                     ...
# 139237                      False                   False
# 139238                      False                   False
# 139240                      False                   False
# 139241                      False                   False
# 139242                      False                   False
#
#         missing_coords_flag zero_coords_flag positive_longitude_flag  \
# 0                     False            False                   False
# 1                     False            False                   False
# 3                     False            False                   False
# 5                     False            False                   False
# 6                     False            False                   False
# ...                     ...              ...                     ...
# 139237                False            False                   False
# 139238                False            False                   False
# 139240                False            False                   False
# 139241                False            False                   False
# 139242                False            False                   False
#
#        out_of_bounds_flag flag_DaysOnMarket flag_LotSizeSquareFeet  \
# 0                   False             False                  False
# 1                   False             False                   True
# 3                   False             False                  False
# 5                   False             False                  False
# 6                   False             False                  False
# ...                   ...               ...                    ...
# 139237              False             False                  False
# 139238              False              True                   True
# 139240              False             False                  False
# 139241              False             False                  False
# 139242              False              True                  False
#
#        flag_ClosePrice
# 0                False
# 1                False
# 3                False
# 5                False
# 6                False
# ...                ...
# 139237           False
# 139238           False
# 139240           False
# 139241           False
# 139242           False
#
# [81332 rows x 99 columns]

# %%
df_listing_week7 = listing_clean[
    (listing_clean['DaysOnMarket'] >= lower['DaysOnMarket']) &
    (listing_clean['DaysOnMarket'] <= upper['DaysOnMarket']) &

    (listing_clean['LotSizeSquareFeet'] >= lower['LotSizeSquareFeet']) &
    (listing_clean['LotSizeSquareFeet'] <= upper['LotSizeSquareFeet']) &

    (listing_clean['ClosePrice'] >= lower['ClosePrice']) &
    (listing_clean['ClosePrice'] <= upper['ClosePrice'])
].copy()

# %%
df_listing_week7
# Out:
#         OriginalListPrice  ListingKey                 ListAgentEmail  \
# 29              1,530,000  1159571850              royfenn@gmail.com
# 44                    NaN  1159569217  rtrevino@interorealestate.com
# 102               580,000  1159548054      Sawyer@MesaProperties.net
# 117             1,300,000  1159541083        kimberlydoner@gmail.com
# 172             1,800,000  1159508997          courtneyp@serhant.com
# ...                   ...         ...                            ...
# 139202          1,339,800  1153004987                            NaN
# 139210          2,680,000  1152805480                            NaN
# 139219          2,295,000  1152522022                            NaN
# 139223          1,050,000  1152274870                            NaN
# 139232          1,199,000  1151634071                            NaN
#
#         CloseDate  ClosePrice ListAgentFirstName ListAgentLastName  Latitude  \
# 29     2026-05-05   1,530,000                Roy              Fenn        34
# 44     2026-04-24   1,750,000               Rick           Trevino        37
# 102    2026-05-05     580,000             SAWYER            SHWETZ        34
# 117    2026-05-01   1,300,000                Kim             Doner        34
# 172    2026-05-01   1,800,000           Courtney            Poulos        33
# ...           ...         ...                ...               ...       ...
# 139202 2026-04-07   1,340,000              Robin             Young        38
# 139210 2026-04-09   2,728,000              Huili              Liao        38
# 139219 2026-03-16   2,380,000               Lisa             Doyle        38
# 139223 2026-03-24   1,050,000            Heather             Gowdy        38
# 139232 2026-04-07   1,485,000             Andrea            Gordon        38
#
#         Longitude          UnparsedAddress  ... year_month  \
# 29           -118          17 Sedoso Court  ...    2026-04
# 44           -122      919 Willow Glen Way  ...    2026-04
# 102          -118           1429 W Fawn St  ...    2026-04
# 117          -118       1617 Flower Avenue  ...    2026-04
# 172          -117       1864 Hill Top Lane  ...    2026-04
# ...           ...                      ...  ...        ...
# 139202       -122      6364 Honeysuckle Dr  ...    2026-03
# 139210       -122  39438 Humpback Whale Rd  ...    2026-03
# 139219       -122          286 Via Cima Ct  ...    2026-03
# 139223       -122        1875 Lamplight Ct  ...    2026-03
# 139232       -122          1100 Miller Ave  ...    2026-03
#
#         purchase_after_close_flag  negative_timeline_flag  \
# 29                          False                   False
# 44                          False                   False
# 102                         False                   False
# 117                         False                   False
# 172                         False                   False
# ...                           ...                     ...
# 139202                      False                   False
# 139210                      False                   False
# 139219                      False                   False
# 139223                      False                   False
# 139232                      False                   False
#
#         missing_coords_flag zero_coords_flag positive_longitude_flag  \
# 29                    False            False                   False
# 44                    False            False                   False
# 102                   False            False                   False
# 117                   False            False                   False
# 172                   False            False                   False
# ...                     ...              ...                     ...
# 139202                False            False                   False
# 139210                False            False                   False
# 139219                False            False                   False
# 139223                False            False                   False
# 139232                False            False                   False
#
#        out_of_bounds_flag flag_DaysOnMarket flag_LotSizeSquareFeet  \
# 29                  False             False                  False
# 44                  False             False                  False
# 102                 False             False                  False
# 117                 False             False                  False
# 172                 False             False                  False
# ...                   ...               ...                    ...
# 139202              False             False                  False
# 139210              False             False                  False
# 139219              False             False                  False
# 139223              False             False                  False
# 139232              False             False                  False
#
#        flag_ClosePrice
# 29               False
# 44               False
# 102              False
# 117              False
# 172              False
# ...                ...
# 139202           False
# 139210           False
# 139219           False
# 139223           False
# 139232           False
#
# [9728 rows x 99 columns]

# %%
import matplotlib.pyplot as plt

cols = ['ClosePrice', 'LotSizeSquareFeet', 'DaysOnMarket']

fig, axes = plt.subplots(1, len(cols), figsize=(5 * len(cols), 5))

for i, col in enumerate(cols):
    df_listing_week7[[col]].boxplot(ax=axes[i])
    axes[i].set_title(f"{col}")

fig.suptitle("After Outlier Removal (Week 7)", fontsize=14)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

cols = ['ClosePrice', 'LotSizeSquareFeet', 'DaysOnMarket']

fig, axes = plt.subplots(len(cols), 2, figsize=(12, 5 * len(cols)))

for i, col in enumerate(cols):
    listing[[col]].boxplot(ax=axes[i, 0])
    axes[i, 0].set_title(f"{col} — Before")

    df_listing_week7[[col]].boxplot(ax=axes[i, 1])
    axes[i, 1].set_title(f"{col} — After")

plt.tight_layout()
plt.show()

# %%
columns_to_keep = [
    # Prices
    "ClosePrice",
    "ListPrice",
    "OriginalListPrice",

    # Property details
    "LivingArea",
    "LotSizeSquareFeet",
    "LotSizeAcres",
    "BedroomsTotal",
    "BathroomsTotalInteger",
    "YearBuilt",

    # Dates
    "CloseDate",
    "PurchaseContractDate",
    "ListingContractDate",
    "ContractStatusChangeDate",

    # Market
    "DaysOnMarket",

    # Location
    "Latitude",
    "Longitude",
    "CountyOrParish",
]

df_sold_week7 = df_sold_week7[[col for col in columns_to_keep if col in df_sold_week7.columns]]
df_listing_week7 = df_listing_week7[[col for col in columns_to_keep if col in df_listing_week7.columns]]

# %%
df_listing_week7
# Out:
#         ClosePrice  ListPrice  OriginalListPrice  LivingArea  \
# 29       1,530,000  1,530,000          1,530,000       2,462
# 44       1,750,000  1,750,000                NaN       1,092
# 102        580,000    580,000            580,000       1,314
# 117      1,300,000  1,300,000          1,300,000       1,666
# 172      1,800,000  1,800,000          1,800,000       1,368
# ...            ...        ...                ...         ...
# 139202   1,340,000  1,339,800          1,339,800       1,379
# 139210   2,728,000  2,680,000          2,680,000       3,490
# 139219   2,380,000  2,295,000          2,295,000       2,576
# 139223   1,050,000  1,050,000          1,050,000       1,747
# 139232   1,485,000  1,199,000          1,199,000       2,044
#
#         LotSizeSquareFeet  LotSizeAcres  BedroomsTotal  BathroomsTotalInteger  \
# 29                  4,622             0              3                      3
# 44                  8,200             0              2                      1
# 102                 6,054             0              4                      2
# 117                 6,000             0              2                      2
# 172                 7,841             0              3                      2
# ...                   ...           ...            ...                    ...
# 139202             10,197             0              3                      2
# 139210              4,800             0              5                      5
# 139219             14,400             0              4                      4
# 139223              2,940             0              2                      2
# 139232              5,900             0              3                      2
#
#         YearBuilt  CloseDate PurchaseContractDate ListingContractDate  \
# 29          2,018 2026-05-05           2026-04-02          2026-04-01
# 44          1,928 2026-04-24           2026-04-24          2026-04-24
# 102         1,957 2026-05-05           2026-04-08          2026-04-06
# 117         1,959 2026-05-01           2026-04-01          2026-04-01
# 172         1,983 2026-05-01           2026-04-13          2026-04-11
# ...           ...        ...                  ...                 ...
# 139202      1,965 2026-04-07           2026-03-17          2026-03-03
# 139210      2,019 2026-04-09           2026-03-27          2026-03-05
# 139219      1,956 2026-03-16           2026-03-09          2026-03-03
# 139223      1,981 2026-03-24           2026-03-10          2026-03-02
# 139232      1,952 2026-04-07           2026-03-19          2026-03-11
#
#        ContractStatusChangeDate  DaysOnMarket  Latitude  Longitude  \
# 29                   2026-05-05             0        34       -118
# 44                   2026-04-24             0        37       -122
# 102                  2026-05-05             0        34       -118
# 117                  2026-05-01             0        34       -118
# 172                  2026-05-01             2        33       -117
# ...                         ...           ...       ...        ...
# 139202               2026-04-07            14        38       -122
# 139210               2026-04-09            22        38       -122
# 139219               2026-03-16             6        38       -122
# 139223               2026-03-24             8        38       -122
# 139232               2026-04-07             8        38       -122
#
#         CountyOrParish
# 29              Orange
# 44         Santa Clara
# 102     San Bernardino
# 117        Los Angeles
# 172          San Diego
# ...                ...
# 139202         Alameda
# 139210         Alameda
# 139219    Contra Costa
# 139223    Contra Costa
# 139232         Alameda
#
# [9728 rows x 17 columns]

# %%
df_listing_week7.dtypes
# Out:
# ClosePrice                         float64
# ListPrice                          float64
# OriginalListPrice                  float64
# LivingArea                         float64
# LotSizeSquareFeet                  float64
# LotSizeAcres                       float64
# BedroomsTotal                      float64
# BathroomsTotalInteger              float64
# YearBuilt                          float64
# CloseDate                   datetime64[ns]
# PurchaseContractDate        datetime64[ns]
# ListingContractDate         datetime64[ns]
# ContractStatusChangeDate    datetime64[ns]
# DaysOnMarket                         int64
# Latitude                           float64
# Longitude                          float64
# CountyOrParish                      object
# dtype: object

# %%
df_sold_week7
# Out:
#         ClosePrice  ListPrice  OriginalListPrice  LivingArea  \
# 7        1,995,000  1,995,000          1,995,000       3,524
# 9          984,000    984,000            984,000       1,573
# 10       1,225,000  1,250,000          1,250,000       2,889
# 11         910,000    910,000            910,000       1,650
# 12       1,825,000  1,849,000          1,849,000       1,863
# ...            ...        ...                ...         ...
# 579673   1,680,000  1,727,000          2,009,000       2,308
# 579684     722,000    680,000            680,000       1,319
# 579759   1,585,000  1,499,000          1,699,000       2,570
# 579802   1,090,000  1,150,000          1,150,000       1,489
# 579823     850,000    965,000            995,000       1,649
#
#         LotSizeSquareFeet  LotSizeAcres  BedroomsTotal  BathroomsTotalInteger  \
# 7                  18,295             0              4                      5
# 9                   6,500             0              3                      2
# 10                  5,338             0              3                      4
# 11                  8,075             0              3                      2
# 12                  6,172             0              4                      2
# ...                   ...           ...            ...                    ...
# 579673              8,276             0              5                      3
# 579684             18,223             0              3                      2
# 579759              7,411             0              3                      4
# 579802              5,991             0              3                      2
# 579823             18,495             0              2                      2
#
#         YearBuilt  CloseDate PurchaseContractDate ListingContractDate  \
# 7           2,004 2024-09-30           2024-09-30          2024-09-30
# 9           1,960 2024-09-30           2024-08-31          2024-08-30
# 10          2,007 2024-09-30           2024-08-09          2024-08-02
# 11          1,964 2024-09-30           2024-09-30          2024-09-17
# 12          1,949 2024-09-30           2024-09-30          2024-09-30
# ...           ...        ...                  ...                 ...
# 579673      1,966 2026-04-10           2026-02-07          2025-07-30
# 579684      1,985 2026-04-09           2026-03-09          2025-07-29
# 579759      1,956 2026-04-07           2026-03-07          2025-07-17
# 579802      1,945 2026-04-23           2026-02-26          2025-07-10
# 579823      1,981 2026-04-03           2026-02-13          2025-07-07
#
#        ContractStatusChangeDate  DaysOnMarket  Latitude  Longitude  \
# 7                    2024-09-30             0        34       -116
# 9                    2024-09-30             0        33       -117
# 10                   2024-09-30             0        34       -117
# 11                   2024-09-30             0        34       -118
# 12                   2024-09-30             0        34       -118
# ...                         ...           ...       ...        ...
# 579673               2026-04-10            77        34       -120
# 579684               2026-04-09            37        34       -119
# 579759               2026-04-07            26        34       -118
# 579802               2026-04-23            32        34       -118
# 579823               2026-04-03            86        34       -118
#
#         CountyOrParish
# 7            Riverside
# 9            San Diego
# 10      San Bernardino
# 11              Orange
# 12         Los Angeles
# ...                ...
# 579673   Santa Barbara
# 579684     Los Angeles
# 579759     Los Angeles
# 579802     Los Angeles
# 579823     Los Angeles
#
# [243866 rows x 17 columns]

# %%
df_sold_week7.dtypes
# Out:
# ClosePrice                         float64
# ListPrice                          float64
# OriginalListPrice                  float64
# LivingArea                         float64
# LotSizeSquareFeet                  float64
# LotSizeAcres                       float64
# BedroomsTotal                      float64
# BathroomsTotalInteger              float64
# YearBuilt                          float64
# CloseDate                   datetime64[ns]
# PurchaseContractDate        datetime64[ns]
# ListingContractDate         datetime64[ns]
# ContractStatusChangeDate    datetime64[ns]
# DaysOnMarket                         int64
# Latitude                           float64
# Longitude                          float64
# CountyOrParish                      object
# dtype: object

# %% [markdown]
# git add .
# git commit -m "your message"
# git pull origin main --rebase
# git push origin main
