# %% [markdown]
# # IDX Data Analyst Internship

# %% [markdown]
# ## Week 1
# #### downloading the files, setting up python, setting up git, cleaning data.

# %%
#Imports
import pandas as pd
import crmls_listed
import crmls_sold

# %%
import glob

# %%
df_listings= pd.read_csv("CRMLSListing202602.csv")
df_sold = pd.read_csv("CRMLSSold202602.csv")

# %% [markdown]
# ### Displaying the data frames

# %%
glob.glob("*.csv")
# Out:
# ['CRMLSListing202602.csv', 'CRMLSSold202602.csv']

# %%
len(glob.glob("CRMLSSold*.csv"))
# Out:
# 1

# %%
sold_files = glob.glob("CRMLSSold*.csv")
listed_files = glob.glob("CRMLSListing*.csv")

print(len(sold_files))
print(len(listed_files))
# Out:
# 1
# 1

# %%
import os
os.listdir()
# Out:
# ['.DS_Store',
#  'crmls_sold.py',
#  'CRMLSListing202602.csv',
#  '__pycache__',
#  'README.md',
#  '.gitignore',
#  'CRMLSSold202602.csv',
#  '.git',
#  'crmls_listed.py',
#  'analysis.ipynb',
#  'raw']

# %%
sold_files = glob.glob("raw/CRMLSSold*.csv")
df_sold = pd.concat([pd.read_csv(f, low_memory= False) for f in sold_files], ignore_index=True)

# %%
df_listings = pd.concat(
    [pd.read_csv(f, low_memory=False) for f in listed_files],
    ignore_index=True)

# %%
# Looking at the original data set 
df_sold
# Out:
#                    BuyerAgentAOR              ListAgentAOR Flooring ViewYN  \
# 0                        Arcadia                   Arcadia      NaN  False
# 1                         Conejo                    Conejo      NaN   True
# 2                   OrangeCounty              OrangeCounty      NaN   True
# 3       SouthwestRiversideCounty  SouthwestRiversideCounty      NaN   True
# 4                     HighDesert                HighDesert      NaN   True
# ...                          ...                       ...      ...    ...
# 532590                       NaN                       NaN      NaN    NaN
# 532591                       NaN                       NaN      NaN   True
# 532592                       NaN                       NaN      NaN   True
# 532593                       NaN                       NaN      NaN  False
# 532594                       NaN                       NaN      NaN   True
#
#        WaterfrontYN BasementYN PoolPrivateYN  OriginalListPrice  ListingKey  \
# 0               NaN        NaN         False          1130000.0   538338723
# 1               NaN        NaN           NaN          1795000.0   535502637
# 2               NaN        NaN           NaN            99000.0   495549184
# 3               NaN        NaN           NaN            40000.0   446937009
# 4               NaN        NaN           NaN            59900.0   446912267
# ...             ...        ...           ...                ...         ...
# 532590          NaN        NaN           NaN           649000.0  1008475397
# 532591          NaN        NaN           NaN            75689.0  1003434877
# 532592          NaN        NaN           NaN           275000.0  1002713752
# 532593          NaN        NaN         False            10000.0  1002447928
# 532594          NaN        NaN           NaN          1600000.0  1001660596
#
#                               ListAgentEmail  ... PostalCode  AssociationFee  \
# 0                        espi.bagwell@kw.com  ...      91016             0.0
# 1                         david@mabryflp.com  ...      93021             NaN
# 2                Jaredengberg@rocketmail.com  ...      92283             0.0
# 3                   Julie@whitehornhomes.com  ...      92530             0.0
# 4                    nadinesells4u@gmail.com  ...      92327             0.0
# ...                                      ...  ...        ...             ...
# 532590              chiggamasta424@gmail.com  ...      90805             NaN
# 532591        jhisquierdo@lee-associates.com  ...      92371             NaN
# 532592                MLS@DaltonRealtors.com  ...      92082             0.0
# 532593  Tazzie@CoronadoPremierProperties.com  ...      92118             0.0
# 532594                diana@countryqueen.com  ...      91765           294.0
#
#        LotSizeSquareFeet MiddleOrJuniorSchoolDistrict  latfilled  lonfilled  \
# 0                14390.0                          NaN        NaN        NaN
# 1               666032.0                          NaN        NaN        NaN
# 2               871200.0                          NaN        NaN        NaN
# 3                16553.0                          NaN        NaN        NaN
# 4               275800.0                          NaN        NaN        NaN
# ...                  ...                          ...        ...        ...
# 532590            4682.0                          NaN        NaN        NaN
# 532591          946123.0                          NaN        NaN        NaN
# 532592          619859.0                          NaN        NaN        NaN
# 532593               NaN                          NaN        NaN        NaN
# 532594           52212.0                          NaN        NaN        NaN
#
#        OriginatingSystemName OriginatingSystemSubName  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ...                      ...                      ...
# 532590                   NaN                      NaN
# 532591                   NaN                      NaN
# 532592                   NaN                      NaN
# 532593                   NaN                      NaN
# 532594                   NaN                      NaN
#
#         BuyerAgencyCompensationType  BuyerAgencyCompensation
# 0                               NaN                      NaN
# 1                               NaN                      NaN
# 2                               NaN                      NaN
# 3                               NaN                      NaN
# 4                               NaN                      NaN
# ...                             ...                      ...
# 532590                        Item1                      2.5
# 532591                        Item1                      4.0
# 532592                        Item1                      2.0
# 532593                         Item                    100.0
# 532594                        Item1                      2.0
#
# [532595 rows x 84 columns]

# %%
#Looking at the original data set
df_listings
# Out:
#        OriginalListPrice  ListingKey   CloseDate  ClosePrice  \
# 0              1100000.0  1157171473         NaN         NaN
# 1              2130000.0  1157170900  2026-04-09   2130000.0
# 2              1199000.0  1157170763         NaN         NaN
# 3               530000.0  1157170224  2026-04-07    530000.0
# 4               225000.0  1157169737         NaN         NaN
# ...                  ...         ...         ...         ...
# 31405             4950.0  1149458718         NaN         NaN
# 31406             1699.0  1146439434         NaN         NaN
# 31407           350000.0  1146104836         NaN         NaN
# 31408             1325.0  1107246684         NaN         NaN
# 31409             6000.0  1063377179         NaN         NaN
#
#       ListAgentFirstName ListAgentLastName   Latitude   Longitude  \
# 0              Cassandra              Diep  34.076588 -118.085541
# 1                 Briant         Patterson  33.651866 -117.898412
# 2                 Audrey             Huang  34.095744 -118.137994
# 3                   Nick            Rogers  33.036771 -116.868485
# 4                   Tina            Quiroz  33.861935 -116.254086
# ...                  ...               ...        ...         ...
# 31405           Alphonso           Lascano  34.044402 -118.365074
# 31406               Gene             Smith  38.115612 -122.267146
# 31407              Jason          Lipovsky  33.139128 -117.053881
# 31408              Kathy              Lund  32.572312 -117.034778
# 31409              Jaime              Rook  33.162293 -117.266434
#
#                UnparsedAddress      PropertyType  ...  MainLevelBedrooms  \
# 0            3821 Earle Avenue       Residential  ...                1.0
# 1             2342 Westminster       Residential  ...                6.0
# 2      312 N Marguerita Avenue       Residential  ...                NaN
# 3              708 12th street       Residential  ...                NaN
# 4                0 Vacant Land              Land  ...                NaN
# ...                        ...               ...  ...                ...
# 31405    1716 S Genesee Avenue  ResidentialLease  ...                NaN
# 31406           124 Benson Ave  ResidentialLease  ...                NaN
# 31407   475 N Midway Drive 169       Residential  ...                0.0
# 31408        4589 Casa nova ct  ResidentialLease  ...                5.0
# 31409         4717 Majorca Way  ResidentialLease  ...                NaN
#
#        NewConstructionYN  GarageSpaces    HighSchoolDistrict PostalCode  \
# 0                  False           2.0              Rosemead      91770
# 1                  False           2.0  Newport Mesa Unified      92627
# 2                    NaN           2.0                   NaN      91801
# 3                  False           2.0                   NaN      92065
# 4                  False           NaN                   NaN      92241
# ...                  ...           ...                   ...        ...
# 31405              False           NaN                   NaN      90019
# 31406              False           1.0                   NaN      94590
# 31407                NaN           0.0       Escondido Union      92027
# 31408              False           2.0                 Other      92154
# 31409                NaN           2.0     Oceanside Unified      92056
#
#                 BuyerOfficeName.1 AssociationFee LotSizeSquareFeet  \
# 0                             NaN            0.0            7212.0
# 1      Harcourts Prime Properties            0.0            8276.0
# 2                             NaN            NaN            7527.0
# 3          Coldwell Banker Realty            NaN               NaN
# 4                             NaN            0.0          210395.0
# ...                           ...            ...               ...
# 31405                         NaN            NaN            4886.0
# 31406                         NaN            NaN           15681.0
# 31407                         NaN          400.0          261360.0
# 31408                         NaN            0.0            2224.0
# 31409                         NaN            NaN            3519.0
#
#       MiddleOrJuniorSchoolDistrict        UnparsedAddress.1
# 0                              NaN        3821 Earle Avenue
# 1                              NaN         2342 Westminster
# 2                              NaN  312 N Marguerita Avenue
# 3                              NaN          708 12th street
# 4                              NaN            0 Vacant Land
# ...                            ...                      ...
# 31405                          NaN    1716 S Genesee Avenue
# 31406                          NaN           124 Benson Ave
# 31407                          NaN   475 N Midway Drive 169
# 31408                          NaN        4589 Casa nova ct
# 31409                          NaN         4717 Majorca Way
#
# [31410 rows x 81 columns]

# %% [markdown]
# #### Creating new data frames named df_sold_residential, and df_listings_residential, that contain only observations of residential homes.

# %%
# Looking at the property types in the data set before filtering
df_sold['PropertySubType'].value_counts()
# single family residence seems to be the largest sold property type
# Out:
# PropertySubType
# SingleFamilyResidence    326253
# Condominium               92138
# Townhouse                 30770
# Apartment                 11795
# Duplex                    10090
# ManufacturedOnLand         5427
# Quadruplex                 3156
# Triplex                    3104
# StockCooperative           1802
# MixedUse                   1615
# Office                     1436
# Retail                      952
# Industrial                  612
# Cabin                       445
# Studio                      380
# Business                    358
# Warehouse                   266
# RoomingHouse                246
# SpecialPurpose              134
# MultiFamily                 125
# BoatSlip                    104
# Agriculture                  78
# UnimprovedLand               67
# OwnYourOwn                   67
# WaterPositionWithLand        64
# Loft                         62
# MobileHome                   55
# ManufacturedHome             52
# Timeshare                    17
# CoOwnership                  16
# Farm                         16
# HotelMotel                   14
# DeededParking                 7
# Ranch                         3
# Name: count, dtype: int64

# %%
df_listings['PropertyType'].value_counts()
# residential homes are the largest listed property in the data.
# Out:
# PropertyType
# Residential            19997
# ResidentialLease        5964
# Land                    2226
# ResidentialIncome       1318
# ManufacturedInPark       938
# CommercialSale           506
# CommercialLease          354
# BusinessOpportunity      107
# Name: count, dtype: int64

# %%
# filtering csv files to property type == Residential.
df_sold_residential = df_sold[df_sold["PropertyType"]=="Residential"]
df_listings_residential = df_listings[df_listings["PropertyType"] == "Residential"]

# %%
# checking he data sets that have been filtered
df_sold_residential['PropertyType'].value_counts()
# Out:
# PropertyType
# Residential    359471
# Name: count, dtype: int64

# %%
df_listings_residential['PropertyType'].value_counts()
# Out:
# PropertyType
# Residential    19997
# Name: count, dtype: int64

# %% [markdown]
# #### Looking at the number of rows and columns in the data sets.

# %%
df_listings.shape
# Out:
# (31410, 81)

# %%
df_sold.shape
# Out:
# (532595, 84)

# %%
df_listings_residential.shape
# Out:
# (19997, 81)

# %%
df_sold_residential.shape
# Out:
# (359471, 84)

# %% [markdown]
# #### What is the Residential vs. other property type share?

# %%
df_sold['PropertyType'].value_counts(normalize=True) * 100
# Out:
# PropertyType
# Residential            67.494250
# ResidentialLease       22.610990
# Land                    3.254067
# ManufacturedInPark      2.731907
# ResidentialIncome       2.692290
# CommercialSale          0.623551
# CommercialLease         0.524038
# BusinessOpportunity     0.068908
# Name: proportion, dtype: float64

# %% [markdown]
# #### The residential properties make up majority of the data, with 67.4943% share compared to other property types. The second largest share is Residential lease.

# %% [markdown]
# Looking at the columns and the number of rows of the new and old data set. The original data sets are significantly larger compared to the new filtered data sets.
#
# df_listings has 31410 rows and 81 colums, df_sold has 532595 rows and 84 columns.
#
# I expect the new data frames to have the same amount of columns which it did, and the rows to reduce,
#
# df_listings_residential has 19997 rows and 81 columns, and df_sold_residential has 359471 rows and 84 columns.

# %% [markdown]
# Deliverable – Week 1
# Submit a .py script that concatenates all monthly files from January 2024 through the most recently
# completed calendar month into two combined datasets (listings and sold), filters both to PropertyType ==
# ‘Residential’ only, and saves them as new CSVs. Include comments confirming row counts before and
# after concatenation and before and after the Residential filter

# %% [markdown]
# #### Deliverable – Weeks 2–3
# Submit a .py script documenting unique property types found, the filtering logic applied, and a null-count
# summary table. Include a missing value report flagging any columns above 90% null. Produce a numeric
# distribution summary (min, max, mean, median, percentiles) for ClosePrice, LivingArea, and
# DaysOnMarket. Save the filtered dataset as a new CSV.

# %%
#Displaying column names to filter data and create new data frames.
df_sold_residential.columns
# Out:
# Index(['BuyerAgentAOR', 'ListAgentAOR', 'Flooring', 'ViewYN', 'WaterfrontYN',
#        'BasementYN', 'PoolPrivateYN', 'OriginalListPrice', 'ListingKey',
#        'ListAgentEmail', 'CloseDate', 'ClosePrice', 'ListAgentFirstName',
#        'ListAgentLastName', 'Latitude', 'Longitude', 'UnparsedAddress',
#        'PropertyType', 'LivingArea', 'ListPrice', 'DaysOnMarket',
#        'ListOfficeName', 'BuyerOfficeName', 'CoListOfficeName',
#        'ListAgentFullName', 'CoListAgentFirstName', 'CoListAgentLastName',
#        'BuyerAgentMlsId', 'BuyerAgentFirstName', 'BuyerAgentLastName',
#        'FireplacesTotal', 'AssociationFeeFrequency', 'AboveGradeFinishedArea',
#        'ListingKeyNumeric', 'MLSAreaMajor', 'TaxAnnualAmount',
#        'CountyOrParish', 'MlsStatus', 'ElementarySchool', 'AttachedGarageYN',
#        'ParkingTotal', 'BuilderName', 'PropertySubType', 'LotSizeAcres',
#        'SubdivisionName', 'BuyerOfficeAOR', 'YearBuilt', 'StreetNumberNumeric',
#        'ListingId', 'BathroomsTotalInteger', 'City', 'TaxYear',
#        'BuildingAreaTotal', 'BedroomsTotal', 'ContractStatusChangeDate',
#        'ElementarySchoolDistrict', 'CoBuyerAgentFirstName',
#        'PurchaseContractDate', 'ListingContractDate', 'BelowGradeFinishedArea',
#        'BusinessType', 'StateOrProvince', 'CoveredSpaces',
#        'MiddleOrJuniorSchool', 'FireplaceYN', 'Stories', 'HighSchool',
#        'Levels', 'LotSizeDimensions', 'LotSizeArea', 'MainLevelBedrooms',
#        'NewConstructionYN', 'GarageSpaces', 'HighSchoolDistrict', 'PostalCode',
#        'AssociationFee', 'LotSizeSquareFeet', 'MiddleOrJuniorSchoolDistrict',
#        'latfilled', 'lonfilled', 'OriginatingSystemName',
#        'OriginatingSystemSubName', 'BuyerAgencyCompensationType',
#        'BuyerAgencyCompensation'],
#       dtype='object')

# %%
df_listings_residential.columns
# Out:
# Index(['OriginalListPrice', 'ListingKey', 'CloseDate', 'ClosePrice',
#        'ListAgentFirstName', 'ListAgentLastName', 'Latitude', 'Longitude',
#        'UnparsedAddress', 'PropertyType', 'LivingArea', 'ListPrice',
#        'DaysOnMarket', 'ListOfficeName', 'BuyerOfficeName', 'CoListOfficeName',
#        'ListAgentFullName', 'CoListAgentFirstName', 'CoListAgentLastName',
#        'BuyerAgentMlsId', 'BuyerAgentFirstName', 'BuyerAgentLastName',
#        'FireplacesTotal', 'AssociationFeeFrequency', 'AboveGradeFinishedArea',
#        'ListingKeyNumeric', 'MLSAreaMajor', 'TaxAnnualAmount',
#        'CountyOrParish', 'PropertyType.1', 'MlsStatus', 'ElementarySchool',
#        'ListAgentFirstName.1', 'AttachedGarageYN', 'ParkingTotal',
#        'BuilderName', 'PropertySubType', 'LotSizeAcres', 'SubdivisionName',
#        'BuyerOfficeAOR', 'YearBuilt', 'DaysOnMarket.1', 'StreetNumberNumeric',
#        'LivingArea.1', 'ListingId', 'BathroomsTotalInteger', 'City', 'TaxYear',
#        'BuildingAreaTotal', 'BedroomsTotal', 'ContractStatusChangeDate',
#        'Longitude.1', 'ElementarySchoolDistrict', 'CoBuyerAgentFirstName',
#        'PurchaseContractDate', 'ListingContractDate', 'BelowGradeFinishedArea',
#        'BusinessType', 'Latitude.1', 'ListPrice.1', 'StateOrProvince',
#        'CoveredSpaces', 'MiddleOrJuniorSchool', 'FireplaceYN', 'Stories',
#        'HighSchool', 'Levels', 'ListAgentLastName.1', 'CloseDate.1',
#        'LotSizeDimensions', 'LotSizeArea', 'MainLevelBedrooms',
#        'NewConstructionYN', 'GarageSpaces', 'HighSchoolDistrict', 'PostalCode',
#        'BuyerOfficeName.1', 'AssociationFee', 'LotSizeSquareFeet',
#        'MiddleOrJuniorSchoolDistrict', 'UnparsedAddress.1'],
#       dtype='object')

# %% [markdown]
# ### Creatign new data frames with our variables of interest:
#
# #### Key MLS Fields
#
# List Price / Close Price — Transaction pricing data
#
# Square Footage — Property size metrics
#
# (LivingArea)
# Bedrooms / Bathrooms — Property configuration
#
# Property Type — Residential, Condo, etc.
#
# Listing Agent / Brokerage — Agent and firm attribution
#
# Days on Market (DaysOnMarket) — Time-to-sell metric

# %%
df_sold_new = df_sold_residential[["ClosePrice", "ListPrice", "OriginalListPrice", "LivingArea",
                                   "LotSizeAcres", "BedroomsTotal", "BathroomsTotalInteger", "DaysOnMarket", "YearBuilt"]].copy()
df_sold_new.head()
# Out:
#     ClosePrice  ListPrice  OriginalListPrice  LivingArea  LotSizeAcres  \
# 0    1090000.0  1130000.0          1130000.0      2655.0        0.3303
# 7    1995000.0  1995000.0          1995000.0      3524.0        0.4200
# 8    2340000.0  2340000.0          2340000.0      2988.0        0.2732
# 9     984000.0   984000.0           984000.0      1573.0        0.1492
# 10   1225000.0  1250000.0          1250000.0      2889.0        0.1225
#
#     BedroomsTotal  BathroomsTotalInteger  DaysOnMarket  YearBuilt
# 0             3.0                    4.0            26     1971.0
# 7             4.0                    5.0             0     2004.0
# 8             4.0                    3.0             0     1979.0
# 9             3.0                    2.0             0     1960.0
# 10            3.0                    4.0             0     2007.0

# %%
df_listing_new= df_listings_residential[["ClosePrice", "ListPrice", "OriginalListPrice", "LivingArea",
                                   "LotSizeAcres", "BedroomsTotal", "BathroomsTotalInteger", "DaysOnMarket", "YearBuilt"]].copy()
df_listing_new.head()
# Out:
#    ClosePrice  ListPrice  OriginalListPrice  LivingArea  LotSizeAcres  \
# 0         NaN  1100000.0          1100000.0      2410.0        0.1656
# 1   2130000.0  2130000.0          2130000.0      1903.0        0.1900
# 2         NaN  1199000.0          1199000.0      1925.0        0.1728
# 3    530000.0   530000.0           530000.0      1020.0           NaN
# 5         NaN  1990000.0          1990000.0      2557.0        0.1722
#
#    BedroomsTotal  BathroomsTotalInteger  DaysOnMarket  YearBuilt
# 0            4.0                    3.0             0     1990.0
# 1            6.0                    4.0             0     1956.0
# 2            4.0                    2.0             0     1913.0
# 3            2.0                    1.0             0     1960.0
# 5            5.0                    5.0             0     1939.0

# %% [markdown]
# #### Summary statistics of the data frames:

# %%
df_listing_new.describe()
# Out:
#          ClosePrice     ListPrice  OriginalListPrice    LivingArea  \
# count  6.783000e+03  1.999700e+04       1.996400e+04  19986.000000
# mean   1.233658e+06  1.345747e+06       1.480840e+06   1978.072100
# std    1.176476e+06  2.488062e+06       8.990689e+06   1304.650215
# min    2.850000e+04  2.900000e+04       4.250000e+02      0.000000
# 25%    6.445000e+05  5.749990e+05       5.750000e+05   1248.000000
# 50%    9.100000e+05  8.300000e+05       8.450000e+05   1688.000000
# 75%    1.460000e+06  1.385000e+06       1.395000e+06   2337.000000
# max    3.026000e+07  9.135000e+07       8.195000e+08  47044.000000
#
#        LotSizeAcres  BedroomsTotal  BathroomsTotalInteger  DaysOnMarket  \
# count  18422.000000   19988.000000           19997.000000  19997.000000
# mean      15.400446       3.217080               2.660699     23.836926
# std      885.936236       1.186157               1.287351     18.927245
# min        0.000000       0.000000               0.000000    -10.000000
# 25%        0.120000       2.000000               2.000000      8.000000
# 50%        0.170000       3.000000               2.000000     20.000000
# 75%        0.342875       4.000000               3.000000     39.000000
# max    87120.000000      17.000000              20.000000    377.000000
#
#           YearBuilt
# count  19972.000000
# mean    1980.958642
# std       27.022602
# min     1865.000000
# 25%     1962.000000
# 50%     1981.000000
# 75%     2002.000000
# max     2027.000000

# %%
df_sold_new.describe()
# Out:
#          ClosePrice     ListPrice  OriginalListPrice    LivingArea  \
# count  3.594690e+05  3.594710e+05       3.588440e+05  3.592610e+05
# mean   1.188227e+06  1.139268e+06       1.226082e+06  1.907181e+03
# std    6.059275e+06  1.352650e+06       6.927357e+06  2.841294e+04
# min    0.000000e+00  5.250000e+02       0.000000e+00  0.000000e+00
# 25%    5.759030e+05  5.790000e+05       5.880000e+05  1.246000e+03
# 50%    8.250000e+05  8.190000e+05       8.290000e+05  1.640000e+03
# 75%    1.300000e+06  1.295000e+06       1.299000e+06  2.214000e+03
# max    9.895000e+08  1.375000e+08       1.390000e+09  1.702132e+07
#
#        LotSizeAcres  BedroomsTotal  BathroomsTotalInteger   DaysOnMarket  \
# count  3.310180e+05  359462.000000          359404.000000  359471.000000
# mean   7.241010e+01       3.199114               2.530389      36.297106
# std    1.716549e+04       1.065330               1.141028      52.555171
# min    0.000000e+00       0.000000               0.000000    -288.000000
# 25%    1.200000e-01       3.000000               2.000000       8.000000
# 50%    1.662000e-01       3.000000               2.000000      18.000000
# 75%    2.700000e-01       4.000000               3.000000      47.000000
# max    7.810698e+06      45.000000             175.000000   12430.000000
#
#            YearBuilt
# count  359145.000000
# mean     1978.443890
# std        26.238524
# min      1776.000000
# 25%      1960.000000
# 50%      1979.000000
# 75%      1998.000000
# max      2026.000000

# %% [markdown]
# the summary statistics of both the data sets are similar when we look at the the mean, median, and the range of the data. the std deviation varies more in the df_sold_new data set, as compared to the df_listings-new data set, which is to be expected as generally properties sold are closed at a lower price than the list.
#
# Looking at the min and max, in the listing data there is a min value of -10 days on market, which is concerning and needs further inspection. Similar observations can be seen for the sold data set with a value of -288. The max value of Days on market of the sold data being 12430 is also concerning because that is very far from the average days on market.

# %% [markdown]
# ### Creating visual summaries of the variables in the data set, to search for extreme values and externalities. that might be affecting the summary of the data.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.float_format = '{:,.0f}'.format
columns = [
    "ClosePrice", "ListPrice", "OriginalListPrice",
    "LivingArea", "LotSizeAcres", "BedroomsTotal",
    "BathroomsTotalInteger", "DaysOnMarket", "YearBuilt"
]

def analyze_dataset(df, name):
    print(f"\n===== Analysis for {name} =====")
    
    for col in columns:
        print(f"\n--- {col} ---")
        
        # Summary stats
        print(df[col].describe(percentiles=[0.01, 0.05, 0.5, 0.95, 0.99]))
        
        # Outliers (IQR)
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        
        outliers = df[(df[col] < lower) | (df[col] > upper)]
        print(f"Outliers: {len(outliers)}")
        
        # Plots
        plt.figure(figsize=(12,4))
        
        plt.subplot(1,2,1)
        sns.histplot(df[col], kde=True)
        plt.title(f"{name} - {col} Histogram")
        
        plt.subplot(1,2,2)
        sns.boxplot(x=df[col])
        plt.title(f"{name} - {col} Boxplot")
        
        plt.tight_layout()
        plt.show()

# %%
analyze_dataset(df_sold_new, "Sold Data")
analyze_dataset(df_listing_new, "Listings Data")
# Out:
# ===== Analysis for Sold Data =====
#
# --- ClosePrice ---
# count       359,469
# mean      1,188,227
# std       6,059,275
# min               0
# 1%          205,000
# 5%          340,000
# 50%         825,000
# 95%       2,850,000
# 99%       5,500,000
# max     989,500,000
# Name: ClosePrice, dtype: float64
# Outliers: 26638
# --- ListPrice ---
# count       359,471
# mean      1,139,268
# std       1,352,650
# min             525
# 1%          215,000
# 5%          348,840
# 50%         819,000
# 95%       2,850,000
# 99%       5,650,000
# max     137,500,000
# Name: ListPrice, dtype: float64
# Outliers: 26854
# --- OriginalListPrice ---
# count         358,844
# mean        1,226,082
# std         6,927,357
# min                 0
# 1%            215,000
# 5%            349,900
# 50%           829,000
# 95%         2,899,000
# 99%         5,985,000
# max     1,390,000,000
# Name: OriginalListPrice, dtype: float64
# Outliers: 27935
# --- LivingArea ---
# count      359,261
# mean         1,907
# std         28,413
# min              0
# 1%             604
# 5%             837
# 50%          1,640
# 95%          3,555
# 99%          5,278
# max     17,021,321
# Name: LivingArea, dtype: float64
# Outliers: 15924
# --- LotSizeAcres ---
# count     331,018
# mean           72
# std        17,165
# min             0
# 1%              0
# 5%              0
# 50%             0
# 95%             3
# 99%            11
# max     7,810,698
# Name: LotSizeAcres, dtype: float64
# Outliers: 51845
# --- BedroomsTotal ---
# count   359,462
# mean          3
# std           1
# min           0
# 1%            1
# 5%            2
# 50%           3
# 95%           5
# 99%           6
# max          45
# Name: BedroomsTotal, dtype: float64
# Outliers: 19695
# --- BathroomsTotalInteger ---
# count   359,404
# mean          3
# std           1
# min           0
# 1%            1
# 5%            1
# 50%           2
# 95%           4
# 99%           6
# max         175
# Name: BathroomsTotalInteger, dtype: float64
# Outliers: 16332
# --- DaysOnMarket ---
# count   359,471
# mean         36
# std          53
# min        -288
# 1%            0
# 5%            2
# 50%          18
# 95%         127
# 99%         223
# max      12,430
# Name: DaysOnMarket, dtype: float64
# Outliers: 26929
# --- YearBuilt ---
# count   359,145
# mean      1,978
# std          26
# min       1,776
# 1%        1,912
# 5%        1,930
# 50%       1,979
# 95%       2,022
# 99%       2,025
# max       2,026
# Name: YearBuilt, dtype: float64
# Outliers: 939
# ===== Analysis for Listings Data =====
#
# --- ClosePrice ---
# count        6,783
# mean     1,233,658
# std      1,176,476
# min         28,500
# 1%         222,733
# 5%         370,000
# 50%        910,000
# 95%      2,987,425
# 99%      5,500,000
# max     30,260,000
# Name: ClosePrice, dtype: float64
# Outliers: 438
# --- ListPrice ---
# count       19,997
# mean     1,345,747
# std      2,488,062
# min         29,000
# 1%         193,896
# 5%         330,000
# 50%        830,000
# 95%      3,499,000
# 99%      9,250,000
# max     91,350,000
# Name: ListPrice, dtype: float64
# Outliers: 1646
# --- OriginalListPrice ---
# count        19,964
# mean      1,480,840
# std       8,990,689
# min             425
# 1%          189,000
# 5%          330,000
# 50%         845,000
# 95%       3,575,000
# 99%       9,537,000
# max     819,500,000
# Name: OriginalListPrice, dtype: float64
# Outliers: 1688
# --- LivingArea ---
# count   19,986
# mean     1,978
# std      1,305
# min          0
# 1%         578
# 5%         810
# 50%      1,688
# 95%      3,985
# 99%      6,624
# max     47,044
# Name: LivingArea, dtype: float64
# Outliers: 1011
# --- LotSizeAcres ---
# count   18,422
# mean        15
# std        886
# min          0
# 1%           0
# 5%           0
# 50%          0
# 95%          4
# 99%         14
# max     87,120
# Name: LotSizeAcres, dtype: float64
# Outliers: 3059
# --- BedroomsTotal ---
# count   19,988
# mean         3
# std          1
# min          0
# 1%           1
# 5%           2
# 50%          3
# 95%          5
# 99%          6
# max         17
# Name: BedroomsTotal, dtype: float64
# Outliers: 78
# --- BathroomsTotalInteger ---
# count   19,997
# mean         3
# std          1
# min          0
# 1%           1
# 5%           1
# 50%          2
# 95%          5
# 99%          7
# max         20
# Name: BathroomsTotalInteger, dtype: float64
# Outliers: 1391
# --- DaysOnMarket ---
# count   19,997
# mean        24
# std         19
# min        -10
# 1%           0
# 5%           1
# 50%         20
# 95%         55
# 99%         63
# max        377
# Name: DaysOnMarket, dtype: float64
# Outliers: 24
# --- YearBuilt ---
# count   19,972
# mean     1,981
# std         27
# min      1,865
# 1%       1,912
# 5%       1,930
# 50%      1,981
# 95%      2,025
# 99%      2,026
# max      2,027
# Name: YearBuilt, dtype: float64
# Outliers: 41

# %% [markdown]
# ### Questions to think about:
#
# #### What is the Residential vs. other property type share?
# The residential properties make up majority of the data, with 67.4943% share compared to other property types. The second largest share is Residential lease.
# #### What are the median and average close prices?
# The mean for sold data(close_price) is approximately $1,188,227. Compared tot he sold data, the listings data(close price) has a mean of is approxmaitely $1,233,658, which is close but higher than the sold price, this might be because the final sale of a property is usually at a lower price than the list price.
#
# The median for the sold data(close_price) is 825,000 which is significantly smaller than the mean value, which means the data contains values that might be skewing the results. Comparing this to the median of the list_data (close_price), it is, 910,000 which is also lower than the mean value.
#
# Overall the columns need to be further investigated.
# #### What does the Days on Market distribution look like?
# The days on market distribution has several extreme values that might be due to errors. For the sold_data, 99% of the data is around 223, and for the listing_data 99% of the data is under 63 days.
#
# The extreme values need to be removed, in order for the analysis to be more accurate.
# #### What percentage of homes sold above vs. below list price?
# The value above list_price is 41%, and below is 59% for the sold data set.
#
# #### Are there any apparent date consistency issues (e.g., close date before listing date)?
#
# #### Which counties have the highest median prices?

# %%
#What percentage of homes sold above vs. below list price?
df_sold_new['above_list'] = df_sold_new["ClosePrice"] > df_sold_new["ListPrice"]
df_sold_new['above_list'].value_counts(normalize=True) * 100
# Out:
# above_list
# False   59
# True    41
# Name: proportion, dtype: float64

# %% [markdown]
# ## Week 4-5

# %% [markdown]
# ### Cleaning the data
# ##### 1) Looking at the missing values, which to remove and which to keep.
# ##### 2) changing any quatitative variable with letters inside.

# %%
df_sold_new.isna().sum()
# Out:
# ClosePrice                   2
# ListPrice                    0
# OriginalListPrice          627
# LivingArea                 210
# LotSizeAcres             28453
# BedroomsTotal                9
# BathroomsTotalInteger       67
# DaysOnMarket                 0
# YearBuilt                  326
# dtype: int64

# %%
df_listing_new.isna().sum()
# Out:
# ClosePrice               13214
# ListPrice                    0
# OriginalListPrice           33
# LivingArea                  11
# LotSizeAcres              1575
# BedroomsTotal                9
# BathroomsTotalInteger        0
# DaysOnMarket                 0
# YearBuilt                   25
# dtype: int64

# %% [markdown]
# #### Calculating the percent of null values in the data

# %%
(df_sold_new.isnull().mean() *100).round(4)
# Out:
# ClosePrice               0.0006
# ListPrice                0.0000
# OriginalListPrice        0.1744
# LivingArea               0.0584
# LotSizeAcres             7.9152
# BedroomsTotal            0.0025
# BathroomsTotalInteger    0.0186
# DaysOnMarket             0.0000
# YearBuilt                0.0907
# dtype: float64

# %%
(df_listing_new.isnull().mean()*100).round(4)
# Out:
# ClosePrice               66.0799
# ListPrice                 0.0000
# OriginalListPrice         0.1650
# LivingArea                0.0550
# LotSizeAcres              7.8762
# BedroomsTotal             0.0450
# BathroomsTotalInteger     0.0000
# DaysOnMarket              0.0000
# YearBuilt                 0.1250
# dtype: float64

# %% [markdown]
# git add .
# git commit -m "your message"
# git pull origin main --rebase
# git push origin main
